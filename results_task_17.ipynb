# %% [markdown]
# -----
# #### Задание 17

# %% [markdown]
# ### Федоров Сергей СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]


def poschet(c):
  x = np.degrees(np.arccos(np.array((c[0,0]*c[1,0]+c[0,1]*c[1,1])/(((c[0,0]**2+c[0,1]**2)**(1/2))*((c[1,0]**2+c[1,1]**2)**(1/2))))))
  # print(c)
  # print('cc[00] =',c[0,0], ' c10',c[1,0])
  print(x)

for i in range(0,len(vecs)):
  if i+1 < len(vecs):
    c = np.array([vecs[i], vecs[i+1]])
    poschet(c)




print(np.degrees(np.arccos(0.3)))
# Out:
# 26.929768978657176
# 52.11810012471654
# 28.93131218228952
# 17.18221873278694
# 12.93616487925393
# 13.528763555394045
# 25.940912990670874
# 22.410863566382982
# 1.606112406422336
# 12.683340352964736
# 12.769781665622217
# 6.919422234881825
# 1.323042039316843
# 20.987062124797262
# 47.060558314910736
# 19.405247714637092
# 28.434112413645114
# 26.60048715141599
# 35.77933997050597
# 72.54239687627792

# %% [markdown]
# ### Алексеев Кирилл СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Анчугов Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import math as mt
# def vec_len(p1):
#     return mt.sqrt(p1[0]**2+p1[1]**2)

# def vec_coords(p1, p2):
#     return [p2[0] - p1[0], p2[1]-p1[1]]

# def coords_sum(p1, p2):
#     return p1[0]*p2[0] + p1[1]*p2[1]

# for i in range(0,len(arr)-3):
#     vec_a = vec_coords(arr[i],arr[i+1])
#     vec_b = vec_coords(arr[i+1],arr[i+2])
#     a = vec_len(vec_a)
#     b = vec_len(vec_b)
#     cos_a = coords_sum(vec_a, vec_b)/(a*b)
#     print(mt.degrees(mt.acos(cos_a)))

# %% [markdown]
# ### Акинина Алёна СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vecs1 = np.array(vecs)[1:]-np.array(vecs)[:len(vecs)-1]
norm = np.vectorize(lambda x,y : np.linalg.norm([x,y]))(vecs1[::,::2],vecs1[::,1::2])
pr = np.vectorize(lambda x,y : np.dot(x,y))(vecs1[:len(vecs1)-1:,:],vecs1[1::,:])
angle = np.vectorize(lambda x,y,k,z : np.degrees(np.arccos((x+y)/(k*z))))(pr[::,:1:],pr[:,1::],norm[:len(norm)-1],norm[1:])
angle
# Out:
# array([[175.55830375],
#        [138.45793981],
#        [147.74225374],
#        [168.32571321],
#        [112.24977331],
#        [175.84673112],
#        [ 48.04045581],
#        [121.77525077],
#        [ 87.52292341],
#        [  9.80786227],
#        [109.57589929],
#        [171.29184157],
#        [164.81172237],
#        [138.03627454],
#        [100.39221212],
#        [ 98.44613066],
#        [177.62825691],
#        [ 90.06070719]])

# %% [markdown]
# ### Лисьев Александр СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

vec = lambda x,y: [x[0]-y[0],x[1]-y[1]]
list(map(lambda i:
np.arccos(np.dot(vec(vecs[i],vecs[i+1]),vec(vecs[i+1],vecs[i+2]))/(np.linalg.norm(vec(vecs[i],vecs[i+1]))*np.linalg.norm(vec(vecs[i+1],vecs[i+2]))))*180/np.pi, 
        range(len(vecs)-2)))
# Out:
# [175.55830374989188,
#  138.45793981423697,
#  147.74225374410625,
#  168.3257132101686,
#  112.2497733125092,
#  175.84673111945006,
#  48.04045581010295,
#  121.77525076524348,
#  87.52292341135758,
#  9.807862265016736,
#  109.57589928572553,
#  171.29184156769074,
#  164.81172237189946,
#  138.03627454361373,
#  100.39221212073147,
#  98.44613066272541,
#  177.628256912053,
#  90.06070718659727]

# %% [markdown]
# ### Чердак Александр СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Шелепова Алена СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

l = len(vecs) - 1

for i in range(l):
    a = np.array(vecs[i])
    b = np.array(vecs[i+1])
    ang = np.degrees(np.math.atan2(np.linalg.det([a,b]), np.dot(a,b)))
    print(ang)
# Out:
# 26.929768978657204
# -52.118100124716555
# 28.931312182289513
# -17.182218732786957
# 12.936164879253884
# -13.528763555394013
# 25.94091299067086
# 22.410863566382993
# -1.606112406422153
# -12.683340352964716
# -12.769781665622205
# 6.919422234881802
# -1.323042039316521
# 20.98706212479728
# -47.06055831491074
# 19.40524771463711
# 28.434112413645114
# -26.600487151415983
# -35.779339970505966

# %% [markdown]
# ### Шнейдер Алиса СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
vecs = np.array(vecs)
angl_calc = lambda vec1, vec2: np.arccos(( vec1.dot(vec2)) / (np.linalg.norm(vec1) * np.linalg.norm(vec2)))

for i in range(np.shape(vecs)[0] - 1):
    print("Angle between vec {0} and vec {1} is {2} degree".format(vecs[i], vecs[i + 1], np.degrees(angl_calc(vecs[i], vecs[i + 1]))))
# Out:
# Angle between vec [6.44 5.05] and vec [3.59 7.71] is 26.929768978657176 degree
# Angle between vec [3.59 7.71] and vec [8.81 2.02] is 52.11810012471654 degree
# Angle between vec [8.81 2.02] and vec [8.71 7.8 ] is 28.93131218228952 degree
# Angle between vec [8.71 7.8 ] and vec [5.51 2.53] is 17.18221873278694 degree
# Angle between vec [5.51 2.53] and vec [6.35 4.89] is 12.93616487925393 degree
# Angle between vec [6.35 4.89] and vec [7.88 3.52] is 13.528763555394045 degree
# Angle between vec [7.88 3.52] and vec [4.89 5.83] is 25.940912990670874 degree
# Angle between vec [4.89 5.83] and vec [1.66 5.24] is 22.410863566382982 degree
# Angle between vec [1.66 5.24] and vec [3.1  8.91] is 1.606112406422336 degree
# Angle between vec [3.1  8.91] and vec [5.11 8.22] is 12.683340352964736 degree
# Angle between vec [5.11 8.22] and vec [7.06 7.15] is 12.769781665622217 degree
# Angle between vec [7.06 7.15] and vec [2.15 2.78] is 6.919422234881825 degree
# ...

# %% [markdown]
# ### Зайцева Анастасия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

norm = lambda x,y: np.linalg.norm([x,y])
dot = lambda x,y: np.dot(x,y)
ugo = lambda x1,x2,y,z: np.arccos((x1+x2)/(y*z))*180/np.pi

vecs = np.array(vecs)
vecs1 = vecs[:len(vecs)-1] - vecs[1:]

nor = np.vectorize(norm)
norma = nor(vecs1[::,::2],vecs1[::,1::2])

do = np.vectorize(dot)
dott = do(vecs1[:len(vecs1)-1],vecs1[1:])

ug = np.vectorize(ugo)
ugol = ug(dott[::,::2],dott[::,1::2],norma[:len(norma)-1],norma[1:])
ugol
# Out:
# array([[175.55830375],
#        [138.45793981],
#        [147.74225374],
#        [168.32571321],
#        [112.24977331],
#        [175.84673112],
#        [ 48.04045581],
#        [121.77525077],
#        [ 87.52292341],
#        [  9.80786227],
#        [109.57589929],
#        [171.29184157],
#        [164.81172237],
#        [138.03627454],
#        [100.39221212],
#        [ 98.44613066],
#        [177.62825691],
#        [ 90.06070719]])

# %% [markdown]
# ### Полуяктов Анатолий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Фомин Андрей СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vec1 = np.array(vecs[0:len(vecs) - 1])
vec2 = np.array(vecs[1:len(vecs)])
mas = []
for i in range(len(vec1)):
        mas.append(np.degrees(np.arccos(vec1[i].dot(vec2[i]) / (np.linalg.norm(vec1[i]) * np.linalg.norm(vec2[i])))))
print(mas)
# Out:
# [26.929768978657176, 52.11810012471654, 28.93131218228952, 17.18221873278694, 12.93616487925393, 13.528763555394045, 25.940912990670874, 22.410863566382982, 1.606112406422336, 12.683340352964736, 12.769781665622217, 6.919422234881825, 1.323042039316843, 20.987062124797262, 47.060558314910736, 19.405247714637092, 28.434112413645114, 26.60048715141599, 35.77933997050597]

# %% [markdown]
# ### Марипова Жасмин СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
vecs = np.array(vecs)
def ang(v1,v2):
    return np.arccos(( v1.dot(v2)) / (np.linalg.norm(v1) * np.linalg.norm(v2)))

for i in range(np.shape(vecs)[0] - 1):
    print(i, i + 1, np.degrees(ang(vecs[i], vecs[i + 1])))
# Out:
# 0 1 26.929768978657176
# 1 2 52.11810012471654
# 2 3 28.93131218228952
# 3 4 17.18221873278694
# 4 5 12.93616487925393
# 5 6 13.528763555394045
# 6 7 25.940912990670874
# 7 8 22.410863566382982
# 8 9 1.606112406422336
# 9 10 12.683340352964736
# 10 11 12.769781665622217
# 11 12 6.919422234881825
# 12 13 1.323042039316843
# 13 14 20.987062124797262
# 14 15 47.060558314910736
# 15 16 19.405247714637092
# 16 17 28.434112413645114
# 17 18 26.60048715141599
# 18 19 35.77933997050597

# %% [markdown]
# ### Зоричев Борис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
lst=[]
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

for i in range(0,len(vecs)-1):
    dic = {}
    c = np.dot(vecs[i],vecs[i+1])/np.linalg.norm(vecs[i])/np.linalg.norm(vecs[i+1]) # косинус угла
    angle = arccos(clip(c, -1, 1))
    dic["Кординаты"] = vecs[i],vecs[i+1]
    dic["Угол"] = np.degrees(angle) # сам угол
    lst.append(dic)
lst
# Out:
# [{'Кординаты': ([6.44, 5.05], [3.59, 7.71]), 'Угол': 26.929768978657187},
#  {'Кординаты': ([3.59, 7.71], [8.81, 2.02]), 'Угол': 52.11810012471654},
#  {'Кординаты': ([8.81, 2.02], [8.71, 7.8]), 'Угол': 28.931312182289506},
#  {'Кординаты': ([8.71, 7.8], [5.51, 2.53]), 'Угол': 17.182218732786964},
#  {'Кординаты': ([5.51, 2.53], [6.35, 4.89]), 'Угол': 12.93616487925393},
#  {'Кординаты': ([6.35, 4.89], [7.88, 3.52]), 'Угол': 13.528763555394045},
#  {'Кординаты': ([7.88, 3.52], [4.89, 5.83]), 'Угол': 25.94091299067086},
#  {'Кординаты': ([4.89, 5.83], [1.66, 5.24]), 'Угол': 22.410863566383},
#  {'Кординаты': ([1.66, 5.24], [3.1, 8.91]), 'Угол': 1.606112406422336},
#  {'Кординаты': ([3.1, 8.91], [5.11, 8.22]), 'Угол': 12.683340352964736},
#  {'Кординаты': ([5.11, 8.22], [7.06, 7.15]), 'Угол': 12.769781665622217},
#  {'Кординаты': ([7.06, 7.15], [2.15, 2.78]), 'Угол': 6.919422234881825},
#  {'Кординаты': ([2.15, 2.78], [7.25, 8.94]), 'Угол': 1.323042039316843},
# ...

# %% [markdown]
# ### Сербаев Вадим СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

#1 проверка

import math
from math import degrees

def dotproduct(v1, v2):
    return sum((a*b) for a, b in zip(v1, v2))

def length(v):
    return math.sqrt(dotproduct(v, v))

def angle(v1, v2):
    return math.acos(dotproduct(v1, v2) / (length(v1) * length(v2)))

i = 1
while i<len(vecs)-1:
    print(degrees(angle(vecs[i], vecs[i-1])))
    print(degrees(angle(vecs[i], vecs[i+1])))
    i+=2
    
print("\n")
    
#2  
    
from numpy import (array, dot, arccos, clip)
from numpy.linalg import norm

i = 1

while i<(len(vecs)-1):
    dotproduct = dot(vecs[i],vecs[i-1])/norm(vecs[i])/norm(vecs[i-1])
    angle = arccos(clip(dotproduct, -1, 1))
    print(degrees(angle))
    
    dotproduct = dot(vecs[i],vecs[i+1])/norm(vecs[i])/norm(vecs[i+1])
    angle = arccos(clip(dotproduct, -1, 1))
    print(degrees(angle))
    i+=2
# Out:
# 26.929768978657176
# 52.11810012471654
# 28.93131218228952
# 17.18221873278694
# 12.93616487925393
# 13.528763555394045
# 25.940912990670874
# 22.410863566382982
# 1.606112406422336
# 12.683340352964736
# 12.769781665622217
# 6.919422234881825
# 1.323042039316843
# 20.987062124797262
# 47.060558314910736
# 19.405247714637092
# 28.434112413645114
# 26.60048715141599
#
#
# 26.929768978657187
# 52.11810012471654
# 28.931312182289506
# 17.182218732786964
# 12.93616487925393
# 13.528763555394045
# 25.94091299067086
# 22.410863566383
# 1.606112406422336
# 12.683340352964736
# 12.769781665622245
# 6.919422234881825
# 1.323042039316843
# 20.987062124797262
# 47.06055831491074
# 19.40524771463707
# 28.434112413645128
# 26.600487151416004

# %% [markdown]
# ### Булгаков Виталий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

deg = list(map(lambda i:np.degrees(np.arccos(np.dot(vecs[i], vecs[i + 1]) / np.linalg.norm(vecs[i]) / np.linalg.norm(vecs[i + 1]))), range(len(vecs) - 1)))
for i in range(len(vecs) - 1):
    print('Векторы :' , vecs[i], vecs[i + 1], 'Угол :', deg[i])
    i += 1
# Out:
# Векторы : [6.44, 5.05] [3.59, 7.71] Угол : 26.929768978657187
# Векторы : [3.59, 7.71] [8.81, 2.02] Угол : 52.11810012471654
# Векторы : [8.81, 2.02] [8.71, 7.8] Угол : 28.931312182289506
# Векторы : [8.71, 7.8] [5.51, 2.53] Угол : 17.182218732786964
# Векторы : [5.51, 2.53] [6.35, 4.89] Угол : 12.936164879253928
# Векторы : [6.35, 4.89] [7.88, 3.52] Угол : 13.528763555394045
# Векторы : [7.88, 3.52] [4.89, 5.83] Угол : 25.940912990670856
# Векторы : [4.89, 5.83] [1.66, 5.24] Угол : 22.410863566383
# Векторы : [1.66, 5.24] [3.1, 8.91] Угол : 1.606112406422336
# Векторы : [3.1, 8.91] [5.11, 8.22] Угол : 12.683340352964736
# Векторы : [5.11, 8.22] [7.06, 7.15] Угол : 12.769781665622217
# Векторы : [7.06, 7.15] [2.15, 2.78] Угол : 6.919422234881825
# Векторы : [2.15, 2.78] [7.25, 8.94] Угол : 1.323042039316843
# Векторы : [7.25, 8.94] [1.62, 4.97] Угол : 20.987062124797262
# Векторы : [1.62, 4.97] [8.86, 4.11] Угол : 47.06055831491074
# ...

# %% [markdown]
# ### Андреева Влада СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Клопов Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vectors=list(zip(vecs[:-1],vecs[1:]))
angle=lambda x: np.rad2deg(np.arccos(np.dot(x[0],x[1])/(np.linalg.norm(x[0])*np.linalg.norm(x[1]))))
list(map(angle,vectors))
# Out:
# [26.929768978657176,
#  52.11810012471654,
#  28.93131218228952,
#  17.18221873278694,
#  12.93616487925393,
#  13.528763555394045,
#  25.940912990670874,
#  22.410863566382982,
#  1.606112406422336,
#  12.683340352964736,
#  12.769781665622217,
#  6.919422234881825,
#  1.323042039316843,
#  20.987062124797262,
#  47.060558314910736,
#  19.405247714637092,
#  28.434112413645114,
#  26.60048715141599,
#  35.77933997050597]

# %% [markdown]
# ### Сарахан Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vec = np.array(vecs)
for i in np.arange(0, arr.shape[0] - 1):
    a = arr[i]
    b = arr[i + 1]
    c = np.dot(a, b)/(np.linalg.norm(a) * np.linalg.norm(b))
    print(np.degrees(np.arccos(np.clip(c, -1, 1))))
# Out:
# 26.929768978657176
# 52.11810012471654
# 28.93131218228952
# 17.18221873278694
# 12.93616487925393
# 13.528763555394045
# 25.940912990670874
# 22.410863566382982
# 1.606112406422336
# 12.683340352964736
# 12.769781665622217
# 6.919422234881825
# 1.323042039316843
# 20.987062124797262
# 47.060558314910736
# 19.405247714637092
# 28.434112413645114
# 26.60048715141599
# 35.77933997050597

# %% [markdown]
# ### Старостин Данила СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Стрекнев Денис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

for i in range(len(vecs)-1):
    a=np.array(vecs[i], float)
    b=np.array(vecs[i+1], float)
    cos_angle=np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))
    angle=np.arccos(cos_angle)
    print(np.rad2deg(angle))
# Out:
# 26.929768978657176
# 52.11810012471654
# 28.93131218228952
# 17.182218732786943
# 12.936164879253928
# 13.528763555394045
# 25.940912990670874
# 22.410863566382982
# 1.606112406422336
# 12.683340352964736
# 12.769781665622217
# 6.919422234881825
# 1.323042039316843
# 20.987062124797262
# 47.060558314910736
# 19.405247714637092
# 28.434112413645114
# 26.60048715141599
# 35.77933997050597

# %% [markdown]
# ### Дородный Дмитрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

print([np.arcsin((np.linalg.norm(np.cross(vecs[i], vecs[i+1])))/(np.linalg.norm(vecs[i])*np.linalg.norm(vecs[i+1])))*180/np.pi for i in range(len(vecs)-1)])
# Out:
# [26.929768978657204, 52.11810012471654, 28.931312182289513, 17.182218732786957, 12.936164879253884, 13.528763555394006, 25.940912990670846, 22.410863566382993, 1.6061124064221506, 12.683340352964715, 12.769781665622205, 6.919422234881797, 1.323042039316521, 20.987062124797273, 47.06055831491076, 19.405247714637113, 28.434112413645114, 26.600487151415987, 35.77933997050597]

# %% [markdown]
# ### Шемякин Дмитрий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Никитина Елизавета СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

vecs = np.array(vecs)
def angl(v1,v2):
    return np.arccos(( v1.dot(v2)) / (np.linalg.norm(v1) * np.linalg.norm(v2)))

for i in range(np.shape(vecs)[0] - 1):
    print("Angle between {0} and {1} dots = {2} ".format(i, i + 1, np.degrees(angl(vecs[i], vecs[i + 1]))))
# Out:
# Angle between 0 and 1 dots = 26.929768978657176
# Angle between 1 and 2 dots = 52.11810012471654
# Angle between 2 and 3 dots = 28.93131218228952
# Angle between 3 and 4 dots = 17.182218732786943
# Angle between 4 and 5 dots = 12.936164879253928
# Angle between 5 and 6 dots = 13.528763555394045
# Angle between 6 and 7 dots = 25.940912990670874
# Angle between 7 and 8 dots = 22.410863566382982
# Angle between 8 and 9 dots = 1.606112406422336
# Angle between 9 and 10 dots = 12.683340352964736
# Angle between 10 and 11 dots = 12.769781665622217
# Angle between 11 and 12 dots = 6.919422234881825
# Angle between 12 and 13 dots = 1.323042039316843
# Angle between 13 and 14 dots = 20.987062124797262
# Angle between 14 and 15 dots = 47.060558314910736
# Angle between 15 and 16 dots = 19.405247714637092
# Angle between 16 and 17 dots = 28.434112413645114
# Angle between 17 and 18 dots = 26.60048715141599
# Angle between 18 and 19 dots = 35.77933997050597

# %% [markdown]
# ### Семенов Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
import math
np.set_printoptions(precision=3)
l=[]
vecs=np.array(vecs)
for i in range(len(vecs)-1):
    l.append(vecs[i]@vecs[i+1]/(np.linalg.norm(vecs[i])*np.linalg.norm(vecs[i+1])))
for i in range(len(l)):
    l[i]=round(math.acos(l[i])*180/3.141,3)
print(l)
# Out:
# [26.935, 52.128, 28.937, 17.185, 12.939, 13.531, 25.946, 22.415, 1.606, 12.686, 12.772, 6.921, 1.323, 20.991, 47.069, 19.409, 28.439, 26.606, 35.786]

# %% [markdown]
# ### Шамрин Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
resArr = []
for i in range(1, len(vecs)):
    v1 = np.array(vecs[i])
    v2 = np.array(vecs[i-1])
    resArr.append( np.degrees(np.arccos(np.dot(v1,v2)/(np.linalg.norm(v1)*np.linalg.norm(v2))) ) )
    
resArr
# Out:
# [26.929768978657176,
#  52.11810012471654,
#  28.93131218228952,
#  17.182218732786943,
#  12.936164879253928,
#  13.528763555394045,
#  25.940912990670874,
#  22.410863566382982,
#  1.606112406422336,
#  12.683340352964736,
#  12.769781665622217,
#  6.919422234881825,
#  1.323042039316843,
#  20.987062124797262,
#  47.060558314910736,
#  19.405247714637092,
#  28.434112413645114,
#  26.60048715141599,
#  35.77933997050597]

# %% [markdown]
# ### Щербаков Игорь СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
def vector_list_lens(v): #Используем повторно
    return np.sqrt((v.T)[0]**2+(v.T)[1]**2).T
def calculate_deg_ang(vecs):
    v=np.array(vecs)
    return np.degrees(np.arccos(np.multiply(v[1:], v[:-1]).sum(1)/(vector_list_lens(v[:-1])*vector_list_lens(v[1:]))))
print(calculate_deg_ang(vecs))
# Out:
# [26.92976898 52.11810012 28.93131218 17.18221873 12.93616488 13.52876356
#  25.94091299 22.41086357  1.60611241 12.68334035 12.76978167  6.91942223
#   1.32304204 20.98706212 47.06055831 19.40524771 28.43411241 26.60048715
#  35.77933997]

# %% [markdown]
# ### Шомахов Идар СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]
vecs = np.array(vecs)
def ang(v1,v2):
    return np.arccos(( v1.dot(v2)) / (np.linalg.norm(v1) * np.linalg.norm(v2)))

for i in range(np.shape(vecs)[0] - 1):
    print(i, i + 1, np.degrees(ang(vecs[i], vecs[i + 1])))
# Out:
# 0 1 26.929768978657176
# 1 2 52.11810012471654
# 2 3 28.93131218228952
# 3 4 17.18221873278694
# 4 5 12.93616487925393
# 5 6 13.528763555394045
# 6 7 25.940912990670874
# 7 8 22.410863566382982
# 8 9 1.606112406422336
# 9 10 12.683340352964736
# 10 11 12.769781665622217
# 11 12 6.919422234881825
# 12 13 1.323042039316843
# 13 14 20.987062124797262
# 14 15 47.060558314910736
# 15 16 19.405247714637092
# 16 17 28.434112413645114
# 17 18 26.60048715141599
# 18 19 35.77933997050597

# %% [markdown]
# ### Григорьев Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Фомин Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

angle = lambda vec1, vec2: np.arccos(( vec1.dot(vec2)) / (np.linalg.norm(vec1) * np.linalg.norm(vec2)))
vecs = np.array(vecs)

for i in range(np.shape(vecs)[0] - 1):
    print("Угол между векторами {0} и {1} равен {2}".format(vecs[i], vecs[i + 1], np.degrees(angle(vecs[i], vecs[i + 1]))))
# Out:
# Угол между векторами [6.44 5.05] и [3.59 7.71] равен 26.929768978657176
# Угол между векторами [3.59 7.71] и [8.81 2.02] равен 52.11810012471654
# Угол между векторами [8.81 2.02] и [8.71 7.8 ] равен 28.93131218228952
# Угол между векторами [8.71 7.8 ] и [5.51 2.53] равен 17.18221873278694
# Угол между векторами [5.51 2.53] и [6.35 4.89] равен 12.93616487925393
# Угол между векторами [6.35 4.89] и [7.88 3.52] равен 13.528763555394045
# Угол между векторами [7.88 3.52] и [4.89 5.83] равен 25.940912990670874
# Угол между векторами [4.89 5.83] и [1.66 5.24] равен 22.410863566382982
# Угол между векторами [1.66 5.24] и [3.1  8.91] равен 1.606112406422336
# Угол между векторами [3.1  8.91] и [5.11 8.22] равен 12.683340352964736
# Угол между векторами [5.11 8.22] и [7.06 7.15] равен 12.769781665622217
# Угол между векторами [7.06 7.15] и [2.15 2.78] равен 6.919422234881825
# Угол между векторами [2.15 2.78] и [7.25 8.94] равен 1.323042039316843
# ...

# %% [markdown]
# ### Синицын Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

for i in range(len(vecs) - 1):
    print(np.degrees(np.arccos(np.dot(vecs[i], vecs[i+1]) / (np.sqrt(vecs[i][0]**2 + vecs[i][1]**2) * np.sqrt(vecs[i+1][0]**2 + vecs[i+1][1]**2)))))
# Out:
# 26.929768978657176
# 52.11810012471654
# 28.93131218228952
# 17.18221873278694
# 12.93616487925393
# 13.528763555394045
# 25.940912990670874
# 22.410863566382982
# 1.606112406422336
# 12.683340352964736
# 12.769781665622217
# 6.919422234881825
# 1.323042039316843
# 20.987062124797262
# 47.060558314910736
# 19.405247714637092
# 28.434112413645114
# 26.60048715141599
# 35.77933997050597

# %% [markdown]
# ### Смирнов Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import math
import numpy as np
np.set_printoptions(precision=2)

vecs = np.array(vecs)

def angle(vec1, vec2):
    return math.acos(vec1 @ vec2 / np.linalg.norm(vec1) / np.linalg.norm(vec2)) * 180 / math.pi

angles = np.empty(len(vecs) - 1)
for i in range(len(vecs) - 1):
    angles[i] = angle(vecs[i], vecs[i+1])
    
print(angles)
# Out:
# [26.93 52.12 28.93 17.18 12.94 13.53 25.94 22.41  1.61 12.68 12.77  6.92
#   1.32 20.99 47.06 19.41 28.43 26.6  35.78]

# %% [markdown]
# ### Расторгуева Мария СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Гвасалия Метью СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

print(*list(map(lambda x: 180/np.pi*np.arccos(np.dot(x,vecs[vecs.index(x)+1])/(np.linalg.norm(x)*np.linalg.norm(vecs[vecs.index(x)+1]))),vecs[:-1])), sep = '\n')
# Out:
# 26.929768978657176
# 52.11810012471654
# 28.93131218228952
# 17.18221873278694
# 12.93616487925393
# 13.528763555394045
# 25.940912990670874
# 22.410863566382982
# 1.606112406422336
# 12.683340352964736
# 12.769781665622217
# 6.919422234881825
# 1.323042039316843
# 20.987062124797262
# 47.060558314910736
# 19.405247714637092
# 28.434112413645114
# 26.60048715141599
# 35.77933997050597

# %% [markdown]
# ### Поддубный Михаил СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
list(
    map(
        lambda i:np.degrees(
            np.arccos(
                np.dot(
                    vecs[i], vecs[i+1]
                )/np.linalg.norm(
                    vecs[i]
                )/np.linalg.norm(
                    vecs[i+1]
                )
            )
        ),
        range(0,len(vecs)-1)
    )
)
# Out:
# [26.929768978657187,
#  52.11810012471654,
#  28.931312182289506,
#  17.182218732786964,
#  12.93616487925393,
#  13.528763555394045,
#  25.94091299067086,
#  22.410863566383,
#  1.606112406422336,
#  12.683340352964736,
#  12.769781665622217,
#  6.919422234881825,
#  1.323042039316843,
#  20.987062124797262,
#  47.06055831491074,
#  19.40524771463707,
#  28.434112413645114,
#  26.600487151416004,
#  35.77933997050597]

# %% [markdown]
# ### Миронов Никита СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Шубин Никита СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]
for i in range(len(vecs) - 1):
    print(np.degrees(np.arcsin(np.dot(vecs[i], vecs[i+1])/((((vecs[i][0])**2 + (vecs[i][1])**2)**0.5)*(((vecs[i+1][0])**2 + (vecs[i+1][1])**2)**0.5)))))
# Out:
# 63.07023102134283
# 37.881899875283466
# 61.06868781771048
# 72.81778126721306
# 77.06383512074608
# 76.47123644460596
# 64.05908700932913
# 67.58913643361701
# 88.39388759357767
# 77.31665964703527
# 77.23021833437778
# 83.08057776511818
# 88.67695796068317
# 69.01293787520274
# 42.93944168508927
# 70.59475228536292
# 61.5658875863549
# 63.39951284858402
# 54.22066002949403

# %% [markdown]
# ### Щеглова Полина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

def unit_vector(vector):
    return vector / np.linalg.norm(vector)

def angle_between(v1, v2):
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0))*180/np.pi

print(list(map(angle_between, vecs[:-1], vecs[1:])))
# Out:
# [26.929768978657176, 52.11810012471654, 28.93131218228952, 17.18221873278696, 12.93616487925393, 13.528763555394045, 25.940912990670846, 22.410863566383, 1.6061124064221093, 12.683340352964706, 12.769781665622217, 6.919422234881771, 1.3230420393165676, 20.98706212479728, 47.060558314910736, 19.40524771463711, 28.434112413645114, 26.600487151416004, 35.77933997050597]

# %% [markdown]
# ### Мухамадиева Регина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
import numpy.linalg
vecs = np.array([[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]])
for i in range(len(vecs)-2):
    print(np.dot(vecs[i],vecs[i+1])/(np.sqrt(vecs[i][0]**2+vecs[i][1]**2))*np.sqrt(vecs[i][0]**2+vecs[i][1]**2))
# Out:
# 62.055099999999996
# 47.2021
# 92.49110000000003
# 67.7261
# 47.36019999999999
# 67.2508
# 59.05479999999999
# 38.6666
# 51.834399999999995
# 89.0812
# 94.84960000000001
# 35.056
# 40.44069999999999
# 56.1768
# 34.7799
# 110.54920000000001
# 77.47
# 78.0389

# %% [markdown]
# ### Астраханцев Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vv = np.array(vecs)
ans = np.diagonal(np.transpose(np.dot(vv[1:], np.transpose(vv[:-1])))) /np.linalg.norm(vv[1:], axis=1)/ \
        np.linalg.norm(vv[:-1], axis=1)
ans = 360/2/np.pi * np.arccos(ans)
print(ans)
# Out:
# [26.92976898 52.11810012 28.93131218 17.18221873 12.93616488 13.52876356
#  25.94091299 22.41086357  1.60611241 12.68334035 12.76978167  6.91942223
#   1.32304204 20.98706212 47.06055831 19.40524771 28.43411241 26.60048715
#  35.77933997]

# %% [markdown]
# ### Бесчастных Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
import numpy.linalg as la
arr = np.array(vecs)
for i in np.arange(0, arr.shape[0] - 2):
    cosang = np.dot(arr[i], arr[i+1])
    sinang = la.norm(np.cross(arr[i], arr[i+1]))
    print(np.arctan2(sinang, cosang)*180/np.pi)
# Out:
# 26.929768978657197
# 52.118100124716534
# 28.931312182289513
# 17.182218732786957
# 12.936164879253887
# 13.52876355539401
# 25.94091299067085
# 22.410863566382993
# 1.6061124064221506
# 12.683340352964716
# 12.769781665622205
# 6.919422234881797
# 1.3230420393165212
# 20.987062124797273
# 47.06055831491074
# 19.40524771463711
# 28.434112413645114
# 26.60048715141599

# %% [markdown]
# ### Музаффаров Руфат СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Гаварина Светлана СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

def vec_angle(v1, v2, deg = True):
    ans = np.arccos(np.multiply(vec_a, vec_b).sum(1) / (np.linalg.norm(vec_a, axis=1) * np.linalg.norm(vec_b, axis=1)))
    if deg:
        return np.degrees(ans)
    else:
        return ans
    
vec_a = np.array(vecs[:-1])
vec_b = np.array(vecs[1:])

vec_angle(vec_a, vec_b)
# Out:
# array([26.92976898, 52.11810012, 28.93131218, 17.18221873, 12.93616488,
#        13.52876356, 25.94091299, 22.41086357,  1.60611241, 12.68334035,
#        12.76978167,  6.91942223,  1.32304204, 20.98706212, 47.06055831,
#        19.40524771, 28.43411241, 26.60048715, 35.77933997])

# %% [markdown]
# ### Дундуков Семен СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Бень Таисия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vector = np.array(vecs)
angle = np.diagonal(np.transpose(np.dot(vector[1:], np.transpose(vector[:-1])))) /np.linalg.norm(vector[1:], axis=1)/np.linalg.norm(vector[:-1], axis=1)
angle = 360/2/np.pi * np.arccos(angle)
print(angle)
# Out:
# [26.92976898 52.11810012 28.93131218 17.18221873 12.93616488 13.52876356
#  25.94091299 22.41086357  1.60611241 12.68334035 12.76978167  6.91942223
#   1.32304204 20.98706212 47.06055831 19.40524771 28.43411241 26.60048715
#  35.77933997]

# %% [markdown]
# ### Козликина Татьяна СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

for i in range (len(vecs) - 1):
    v0 = np.array(vecs[i])
    v1 = np.array(vecs[i+1])
    angle = np.math.atan2(np.linalg.det([v0,v1]),np.dot(v0,v1)) #Значение угла в радианах
    angle_2 = np.degrees(angle) #Значение угла в градусах
    print('Значение угла в радианах = %f \nЗначение угла в градусах = %f \n' %(angle, angle_2))
# Out:
# Значение угла в радианах = 0.470013
# Значение угла в градусах = 26.929769
#
# Значение угла в радианах = -0.909632
# Значение угла в градусах = -52.118100
#
# Значение угла в радианах = 0.504947
# Значение угла в градусах = 28.931312
#
# Значение угла в радианах = -0.299886
# Значение угла в градусах = -17.182219
#
# Значение угла в радианах = 0.225779
# Значение угла в градусах = 12.936165
#
# Значение угла в радианах = -0.236121
# Значение угла в градусах = -13.528764
#
# Значение угла в радианах = 0.452754
# Значение угла в градусах = 25.940913
#
# Значение угла в радианах = 0.391143
# Значение угла в градусах = 22.410864
#
# Значение угла в радианах = -0.028032
# Значение угла в градусах = -1.606112
#
# Значение угла в радианах = -0.221366
# Значение угла в градусах = -12.683340
#
# Значение угла в радианах = -0.222875
# Значение угла в градусах = -12.769782
#
# Значение угла в радианах = 0.120767
# Значение угла в градусах = 6.919422
#
# Значение угла в радианах = -0.023091
# ...

# %% [markdown]
# ### Апресян Тигран СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vec

# %% [markdown]
# ### Долотов Фёдор СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Попов Юрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# используя только возможности NumPy рассчитать углы между предыдущим и следующим векторами в градусах
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
#Задание_17
import numpy as np

for i in range (len(vecs) - 1):
    v0 = np.array(vecs[i])
    v1 = np.array(vecs[i+1])
    angle = np.math.atan2(np.linalg.det([v0,v1]), np.dot(v0,v1))
    print(np.degrees(angle))
# Out:
# 26.929768978657204
# -52.118100124716555
# 28.931312182289513
# -17.182218732786957
# 12.936164879253884
# -13.528763555394013
# 25.94091299067086
# 22.410863566382993
# -1.606112406422153
# -12.683340352964716
# -12.769781665622205
# 6.919422234881802
# -1.323042039316521
# 20.98706212479728
# -47.06055831491074
# 19.40524771463711
# 28.434112413645114
# -26.600487151415983
# -35.779339970505966
