# %% [markdown]
# -----
# #### Задание 16

# %% [markdown]
# ### Федоров Сергей СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]
len(vecs)


def creatDelta(c):
  mat = np.ones((3,3))
  mat[0:3, 0:2] = c
  print(mat)
  S = np.absolute(1/2 * np.linalg.det(mat))
  print(S, ' \n')
for i in range(0,len(vecs)):
  if i+2 < len(vecs):
    c = np.array([vecs[i], vecs[i+1],vecs[i+2]])
    creatDelta(c)
# Out:
# [[6.44 5.05 1.  ]
#  [3.59 7.71 1.  ]
#  [8.81 2.02 1.  ]]
# 1.1656500000000032
#
# [[3.59 7.71 1.  ]
#  [8.81 2.02 1.  ]
#  [8.71 7.8  1.  ]]
# 14.801299999999994
#
# [[8.81 2.02 1.  ]
#  [8.71 7.8  1.  ]
#  [5.51 2.53 1.  ]]
# 9.511500000000002
#
# [[8.71 7.8  1.  ]
#  [5.51 2.53 1.  ]
#  [6.35 4.89 1.  ]]
# 1.5626
#
# [[5.51 2.53 1.  ]
#  [6.35 4.89 1.  ]
#  [7.88 3.52 1.  ]]
# 2.3808000000000007
#
# [[6.35 4.89 1.  ]
#  [7.88 3.52 1.  ]
#  [4.89 5.83 1.  ]]
# 0.28100000000000114
#
# [[7.88 3.52 1.  ]
#  [4.89 5.83 1.  ]
#  [1.66 5.24 1.  ]]
# 4.612700000000002
#
# [[4.89 5.83 1.  ]
#  [1.66 5.24 1.  ]
#  [3.1  8.91 1.  ]]
# 5.502249999999999
#
# [[1.66 5.24 1.  ]
#  [3.1  8.91 1.  ]
#  [5.11 8.22 1.  ]]
# 4.18515
#
# [[3.1  8.91 1.  ]
#  [5.11 8.22 1.  ]
#  [7.06 7.15 1.  ]]
# 0.40260000000000173
#
# [[5.11 8.22 1.  ]
#  [7.06 7.15 1.  ]
#  [2.15 2.78 1.  ]]
# 6.887599999999998
#
# [[7.06 7.15 1.  ]
#  [2.15 2.78 1.  ]
#  [7.25 8.94 1.  ]]
# 3.9792999999999963
#
# ...

# %% [markdown]
# ### Алексеев Кирилл СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Анчугов Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
import math as mt

arr = vecs
for i in range(0,len(arr)-3):
    a = np.linalg.norm(arr[i])
    b = np.linalg.norm(arr[i+1])
    c = np.linalg.norm(arr[i+2])
    p = (a+b+c)/2
    if p*(p-a)*(p-b)*(p-c) > 0:
        s = mt.sqrt(p*(p-a)*(p-b)*(p-c))
        print(s)
# Out:
# 31.681022653987984
# 38.191138160606066
# 27.01856044282337
# 22.597311164923468
# 23.37532086111333
# 28.069547063677387
# 20.633312610375963
# 20.91159471081474
# 25.129474515795188
# 40.82938079063747
# 16.96042578642632
# 16.99381215168847
# 25.410371855344316
# 24.966138267398808
# 35.82579199064378
# 41.71739611567187

# %% [markdown]
# ### Акинина Алёна СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]
import numpy as np
vecs1 = np.array(vecs)[:len(vecs)-1]-np.array(vecs)[1:]
vecs2 = np.array(vecs)[:len(vecs)-2]-np.array(vecs)[2:]
norm1 = np.vectorize(lambda x,y : np.linalg.norm([x,y]))(vecs1[::,::2],vecs1[::,1::2])
norm2 = np.vectorize(lambda x,y : np.linalg.norm([x,y]))(vecs2[::,::2],vecs2[::,1::2])
perimeter = np.vectorize(lambda x,y,z : (x+y+z)/2)(norm1[:len(norma1)-1],norm1[1:],norm2[:])
area = np.vectorize(lambda p,x,y,z : np.sqrt(p*(p-x)*(p-y)*(p-z)))(perimeter[:],norm1[:len(norm1)-1],norm1[1:],norm2[:])
area
# Out:
# array([[ 1.16565],
#        [14.8013 ],
#        [ 9.5115 ],
#        [ 1.5626 ],
#        [ 2.3808 ],
#        [ 0.281  ],
#        [ 4.6127 ],
#        [ 5.50225],
#        [ 4.18515],
#        [ 0.4026 ],
#        [ 6.8876 ],
#        [ 3.9793 ],
#        [ 7.2169 ],
#        [16.7923 ],
#        [15.3413 ],
#        [13.8703 ],
#        [ 0.8487 ],
#        [21.8019 ]])

# %% [markdown]
# ### Лисьев Александр СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

norm1 = lambda x:[np.linalg.norm(vec(x[0],x[1])),np.linalg
.norm(vec(x[1],x[2])),np.linalg.norm(vec(x[2],x[0]))]
vec = lambda x,y:[x[0]-y[0],x[1]-y[1]]
list(map(lambda a,p1: np.sqrt(p1*(p1-a[0])*(p1-a[1])*(p1-a[2]))
,list(map(lambda i: norm1(vecs[i:i+3]),range(len(vecs)-2))), 
list(map(lambda i: sum(norm1(vecs[i:i+3]))/2, 
range(len(vecs)-2)))))
# Out:
# [1.1656499999999994,
#  14.80130000000001,
#  9.511499999999996,
#  1.5626000000000189,
#  2.3808000000000007,
#  0.28100000000000724,
#  4.612700000000002,
#  5.502249999999999,
#  4.185149999999999,
#  0.4025999999999968,
#  6.887599999999995,
#  3.9793000000000114,
#  7.21689999999999,
#  16.7923,
#  15.341300000000004,
#  13.870299999999999,
#  0.8486999999999989,
#  21.801899999999993]

# %% [markdown]
# ### Чердак Александр СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Шелепова Алена СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
import numpy as np

vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
for i in range(len(vecs)-2):
    S = abs( 1/2* np.linalg.det( np.array([list(map(lambda x,y: x - y, vecs[i],vecs[i+2])),list( map(lambda x,y: x - y, vecs[i+1],vecs[i+2]))])))
    print(S)
# Out:
# 1.1656500000000012
# 14.801300000000001
# 9.511500000000002
# 1.5626000000000013
# 2.3807999999999994
# 0.2809999999999993
# 4.6126999999999985
# 5.502249999999999
# 4.18515
# 0.402600000000001
# 6.887600000000002
# 3.9792999999999963
# 7.216900000000001
# 16.792299999999994
# 15.341300000000006
# 13.870300000000002
# 0.8486999999999982
# 21.801899999999996

# %% [markdown]
# ### Шнейдер Алиса СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np


vecs = np.array(vecs)


angl_calc = lambda vec1, vec2: np.arccos(( vec1.dot(vec2)) / (np.linalg.norm(vec1) * np.linalg.norm(vec2)))
s_calc = lambda vec1, vec2: 0.5 * np.linalg.norm(vec1) * np.linalg.norm(vec2) * np.sin(angl_calc(vec1, vec2))


for i in range(np.shape(vecs)[0] - 1):
    print("Area {0} = {1}".format(i, s_calc(vecs[i], vecs[i + 1])))
# Out:
# Area 0 = 15.761449999999984
# Area 1 = 30.336650000000002
# Area 2 = 25.56190000000001
# Area 3 = 10.470849999999986
# Area 4 = 5.439200000000019
# Area 5 = 8.09060000000002
# Area 6 = 14.363800000000014
# Area 7 = 7.9728999999999965
# Area 8 = 0.7267000000000842
# Area 9 = 10.024050000000017
# Area 10 = 10.74835000000001
# Area 11 = 2.127150000000006
# Area 12 = 0.4670000000001141
# Area 13 = 10.774849999999994
# Area 14 = 18.687999999999995
# Area 15 = 19.47094999999998
# Area 16 = 20.973749999999995
# Area 17 = 19.5399
# Area 18 = 35.22305

# %% [markdown]
# ### Зайцева Анастасия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

norm = lambda x,y: np.linalg.norm([x,y])
pe = lambda x,y,z: (x+y+z)/2
plo = lambda p,x,y,z: np.sqrt(p*(p-x)*(p-y)*(p-z))

vecs = np.array(vecs)
vecs1 = vecs[:len(vecs)-1] - vecs[1:]
vecs2 = vecs[:len(vecs)-2] - vecs[2:]

nor = np.vectorize(norm)
norma1 = nor(vecs1[::,::2],vecs1[::,1::2])
norma2 = nor(vecs2[::,::2],vecs2[::,1::2])

p = np.vectorize(pe)
per = p(norma1[:len(norma1)-1],norma1[1:],norma2[:])

pl = np.vectorize(plo)
plosh = pl(per[:],norma1[:len(norma1)-1],norma1[1:],norma2[:])

plosh
# Out:
# array([[ 1.16565],
#        [14.8013 ],
#        [ 9.5115 ],
#        [ 1.5626 ],
#        [ 2.3808 ],
#        [ 0.281  ],
#        [ 4.6127 ],
#        [ 5.50225],
#        [ 4.18515],
#        [ 0.4026 ],
#        [ 6.8876 ],
#        [ 3.9793 ],
#        [ 7.2169 ],
#        [16.7923 ],
#        [15.3413 ],
#        [13.8703 ],
#        [ 0.8487 ],
#        [21.8019 ]])

# %% [markdown]
# ### Полуяктов Анатолий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Фомин Андрей СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vec1 = np.array(vecs[0:len(vecs) - 2])
vec2 = np.array(vecs[1:len(vecs) - 1])
vec3 = np.array(vecs[2:len(vecs)])
mas = []
# посчитаем 3 стороны нашего треугольника, используя результаты 17 задачи: a = (b^2 + c^2 - 2bc cos)^(0.5)
# найдя все три стороны, вычислим по формуле Герона
for i in range(len(vec1)):
        # 1 сторона
        a = np.sqrt(np.linalg.norm(vec1[i])**2 + np.linalg.norm(vec2[i])**2 - 2 * np.linalg.norm(vec1[i])*np.linalg.norm(vec2[i])* (vec1[i].dot(vec2[i]) / (np.linalg.norm(vec1[i]) * np.linalg.norm(vec2[i]))))
        # 2 сторона
        b = np.sqrt(np.linalg.norm(vec1[i]) ** 2 + np.linalg.norm(vec3[i])**2 - 2 * np.linalg.norm(vec1[i])*np.linalg.norm(vec3[i]) * (vec1[i].dot(vec3[i]) / (np.linalg.norm(vec1[i]) * np.linalg.norm(vec3[i]))))
        # 3 сторона
        c = np.sqrt(np.linalg.norm(vec2[i]) ** 2 + np.linalg.norm(vec3[i])**2 - 2 * np.linalg.norm(vec2[i])*np.linalg.norm(vec3[i]) * (vec2[i].dot(vec3[i]) / (np.linalg.norm(vec2[i]) * np.linalg.norm(vec3[i]))))
        mas.append((1/4)* np.sqrt((a + b - c)*(a - b + c)*(-a + b + c)*(a + b + c)))
print(mas)
# Out:
# [1.1656499999999554, 14.80129999999998, 9.511499999999993, 1.5626000000000229, 2.380800000000005, 0.2810000000000077, 4.612700000000018, 5.502249999999998, 4.185150000000011, 0.40260000000011514, 6.887600000000013, 3.9793000000000145, 7.216899999999997, 16.792300000000008, 15.34129999999999, 13.870299999999997, 0.8486999999998667, 21.801900000000007]

# %% [markdown]
# ### Марипова Жасмин СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np


vecs = np.array(vecs)

def ang(v1,v2):
    return np.arccos(( v1.dot(v2)) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
    
def area(v1,v2):
    return 0.5 * np.linalg.norm(v1) * np.linalg.norm(v2) * np.sin(ang(v1, v2))

for i in range(np.shape(vecs)[0] - 1):
    print(i, area(vecs[i], vecs[i + 1]))
# Out:
# 0 15.761449999999984
# 1 30.336650000000002
# 2 25.56190000000001
# 3 10.470849999999986
# 4 5.439200000000019
# 5 8.09060000000002
# 6 14.363800000000014
# 7 7.9728999999999965
# 8 0.7267000000000842
# 9 10.024050000000017
# 10 10.74835000000001
# 11 2.127150000000006
# 12 0.4670000000001141
# 13 10.774849999999994
# 14 18.687999999999995
# 15 19.47094999999998
# 16 20.973749999999995
# 17 19.5399
# 18 35.22305

# %% [markdown]
# ### Зоричев Борис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
lst=[]
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]
Vecs=np.asarray(vecs)
for i in range(0,len(vecs)-2):
    dic={}
    A=(Vecs[i][0]*Vecs[i+1][1]+Vecs[i+1][0]*Vecs[i+2][1]+Vecs[i+2][0]*Vecs[i][1]-Vecs[i][1]*Vecs[i+1][0]-Vecs[i+1][1]*Vecs[i+2][0]-Vecs[i+2][1]*Vecs[i][0])/2
    dic["Кординаты"]=vecs[i],vecs[i+1],vecs[i+2]
    dic["Площадь"]=abs(A)
    lst.append(dic)
lst
# Out:
# [{'Кординаты': ([6.44, 5.05], [3.59, 7.71], [8.81, 2.02]),
#   'Площадь': 1.1656499999999959},
#  {'Кординаты': ([3.59, 7.71], [8.81, 2.02], [8.71, 7.8]),
#   'Площадь': 14.801299999999996},
#  {'Кординаты': ([8.81, 2.02], [8.71, 7.8], [5.51, 2.53]),
#   'Площадь': 9.511500000000003},
#  {'Кординаты': ([8.71, 7.8], [5.51, 2.53], [6.35, 4.89]),
#   'Площадь': 1.5625999999999998},
#  {'Кординаты': ([5.51, 2.53], [6.35, 4.89], [7.88, 3.52]),
#   'Площадь': 2.380799999999999},
#  {'Кординаты': ([6.35, 4.89], [7.88, 3.52], [4.89, 5.83]),
#   'Площадь': 0.2809999999999988},
#  {'Кординаты': ([7.88, 3.52], [4.89, 5.83], [1.66, 5.24]),
#   'Площадь': 4.612699999999993},
#  {'Кординаты': ([4.89, 5.83], [1.66, 5.24], [3.1, 8.91]),
#   'Площадь': 5.5022499999999965},
#  {'Кординаты': ([1.66, 5.24], [3.1, 8.91], [5.11, 8.22]),
#   'Площадь': 4.185149999999999},
#  {'Кординаты': ([3.1, 8.91], [5.11, 8.22], [7.06, 7.15]),
#   'Площадь': 0.4026000000000014},
# ...

# %% [markdown]
# ### Сербаев Вадим СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
vecs = [[6.44, 5.05], #без NumPy
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]
for i in range(len(vecs)-2):
    x1 = vecs[i][0]
    y1 = vecs[i][1]
    x2 = vecs[i+1][0]
    y2 = vecs[i+1][1]
    x3 = vecs[i+2][0]
    y3 = vecs[i+2][1]
    S = abs( x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2) ) / 2
    print(S)
# Out:
# 1.1656499999999994
# 14.801300000000001
# 9.5115
# 1.5626000000000033
# 2.3808
# 0.28099999999999925
# 4.612699999999999
# 5.502249999999999
# 4.185150000000001
# 0.40260000000000096
# 6.887599999999999
# 3.979299999999993
# 7.216899999999998
# 16.792299999999997
# 15.3413
# 13.870299999999999
# 0.8486999999999982
# 21.8019

# %% [markdown]
# ### Булгаков Виталий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
s = list(map(lambda i:(1 / 2) * abs(np.cross([vecs[i + 1][0] - vecs[i][0],vecs[i + 1][1] - vecs[i][1]], [vecs[i + 2][0] - vecs[i][0],vecs[i + 2][1] - vecs[i][1]])), range(len(vecs) - 2)))
for i in range(len(vecs) - 2):
    print('Номер треугольника :' , i + 1, 'Площадь :' , s[i], '\n' , 'Координаты треугольника :', [vecs[i], vecs[i + 1], vecs[i + 2]])
    i += 1
# Out:
# Номер треугольника : 1 Площадь : 1.1656499999999999
#  Координаты треугольника : [[6.44, 5.05], [3.59, 7.71], [8.81, 2.02]]
# Номер треугольника : 2 Площадь : 14.801300000000001
#  Координаты треугольника : [[3.59, 7.71], [8.81, 2.02], [8.71, 7.8]]
# Номер треугольника : 3 Площадь : 9.511500000000002
#  Координаты треугольника : [[8.81, 2.02], [8.71, 7.8], [5.51, 2.53]]
# Номер треугольника : 4 Площадь : 1.5626000000000015
#  Координаты треугольника : [[8.71, 7.8], [5.51, 2.53], [6.35, 4.89]]
# Номер треугольника : 5 Площадь : 2.3808000000000002
#  Координаты треугольника : [[5.51, 2.53], [6.35, 4.89], [7.88, 3.52]]
# Номер треугольника : 6 Площадь : 0.28099999999999936
#  Координаты треугольника : [[6.35, 4.89], [7.88, 3.52], [4.89, 5.83]]
# Номер треугольника : 7 Площадь : 4.612699999999999
#  Координаты треугольника : [[7.88, 3.52], [4.89, 5.83], [1.66, 5.24]]
# Номер треугольника : 8 Площадь : 5.502249999999999
# ...

# %% [markdown]
# ### Андреева Влада СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Клопов Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vectors=np.array(vecs)
getVectors=lambda x: (x[1]-x[0],x[2]-x[0])
vectors = list(map(getVectors,list(zip(vectors[:-2],vectors[1:-1],vectors[2:]))))
sinus=lambda x: (1-((np.dot(x[0],x[1]))/(np.linalg.norm(x[0])*np.linalg.norm(x[1])))**2)**0.5
area=lambda x: 0.5*np.linalg.norm(x[0])*np.linalg.norm(x[1])*sinus(x)
list(map(area, vectors))
# Out:
# [1.1656500000000063,
#  14.8013,
#  9.511500000000002,
#  1.5625999999999993,
#  2.3807999999999994,
#  0.2809999999999986,
#  4.6126999999999985,
#  5.50225,
#  4.185149999999998,
#  0.4025999999999884,
#  6.8876,
#  3.979299999999997,
#  7.216899999999999,
#  16.7923,
#  15.3413,
#  13.870300000000002,
#  0.8486999999999981,
#  21.8019]

# %% [markdown]
# ### Сарахан Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
arr = np.array(vecs)
for i in np.arange(0, arr.shape[0] - 2):
    t = np.array([arr[i] - arr[i + 2], arr[i + 1] - arr[i + 2]])
    print(0.5 * abs(np.linalg.det(t)))
# Out:
# 1.1656500000000012
# 14.801300000000001
# 9.511500000000002
# 1.5626000000000013
# 2.3807999999999994
# 0.2809999999999993
# 4.6126999999999985
# 5.502249999999999
# 4.18515
# 0.402600000000001
# 6.887600000000002
# 3.9792999999999963
# 7.216900000000001
# 16.792299999999994
# 15.341300000000006
# 13.870300000000002
# 0.8486999999999982
# 21.801899999999996

# %% [markdown]
# ### Старостин Данила СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Стрекнев Денис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

for i in range(len(vecs)-2):
    a=np.array([vecs[i][0]-vecs[i+1][0], vecs[i][1]-vecs[i+1][1]], float)
    b=np.array([vecs[i][0]-vecs[i+2][0], vecs[i][1]-vecs[i+2][1]], float)
    angle=np.arccos(np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b)))
    print(0.5*np.sin(angle)*np.linalg.norm(a)*np.linalg.norm(b))
# Out:
# 1.1656500000000034
# 14.8013
# 9.5115
# 1.5626
# 2.3807999999999994
# 0.28099999999999853
# 4.612699999999999
# 5.502249999999999
# 4.185149999999999
# 0.4025999999999894
# 6.887600000000001
# 3.979299999999997
# 7.216900000000001
# 16.7923
# 15.341299999999999
# 13.870300000000002
# 0.8486999999999982
# 21.8019

# %% [markdown]
# ### Дородный Дмитрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

print(list(map(lambda x:  np.linalg.norm(np.cross(x[0], x[1]))/2,  [((vecs[i-1][0]-vecs[i][0], vecs[i-1][1]-vecs[i][1]), (vecs[i+1][0]-vecs[i][0], vecs[i+1][1]-vecs[i][1])) for i in range(1, len(vecs)-1)])))
# Out:
# [1.1656499999999985, 14.801300000000001, 9.511500000000002, 1.5626000000000015, 2.3808, 0.2809999999999995, 4.612699999999999, 5.502249999999998, 4.18515, 0.4026000000000012, 6.887600000000001, 3.9793000000000003, 7.216900000000001, 16.792299999999997, 15.3413, 13.870300000000002, 0.8486999999999982, 21.8019]

# %% [markdown]
# ### Шемякин Дмитрий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Никитина Елизавета СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np


vecs = np.array(vecs)

def angl(v1,v2):
    return np.arccos(( v1.dot(v2)) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
    
def s(v1,v2):
    return 0.5 * np.linalg.norm(v1) * np.linalg.norm(v2) * np.sin(angl(v1, v2))

for i in range(np.shape(vecs)[0] - 1):
    print("Area {} = {}".format(i, s(vecs[i], vecs[i + 1])))
# Out:
# Area 0 = 15.761449999999984
# Area 1 = 30.336650000000002
# Area 2 = 25.56190000000001
# Area 3 = 10.470849999999988
# Area 4 = 5.439200000000018
# Area 5 = 8.09060000000002
# Area 6 = 14.363800000000014
# Area 7 = 7.9728999999999965
# Area 8 = 0.7267000000000842
# Area 9 = 10.024050000000017
# Area 10 = 10.74835000000001
# Area 11 = 2.127150000000006
# Area 12 = 0.4670000000001141
# Area 13 = 10.774849999999994
# Area 14 = 18.687999999999995
# Area 15 = 19.47094999999998
# Area 16 = 20.973749999999995
# Area 17 = 19.5399
# Area 18 = 35.22305

# %% [markdown]
# ### Семенов Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
np.set_printoptions(precision=3)
l=[]
vecs=np.array(vecs)
vecs
for i in range(len(vecs)-2):
        l.append(round(abs(1/2*((vecs[i,0]-vecs[i+2,0])*(vecs[i+1,1]-vecs[i+2,1])-(vecs[i+1,0]-vecs[i+2,0])*(vecs[i,1]-vecs[i+2,1]))),2))
#s=abs(1/2((x1-x3)*(y2-y3)-(x2-x3)*(y2-y3)))
print(l)
# Out:
# [1.17, 14.8, 9.51, 1.56, 2.38, 0.28, 4.61, 5.5, 4.19, 0.4, 6.89, 3.98, 7.22, 16.79, 15.34, 13.87, 0.85, 21.8]

# %% [markdown]
# ### Шамрин Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
arrOfAreas = []
for i in range(2, len(vecs)):
    t1 = np.array(vecs[i])
    t2 = np.array(vecs[i-1])
    t3 = np.array(vecs[i-2])
    arrOfAreas.append( np.linalg.norm(np.cross(t2-t1, t3-t1)) )
arrOfAreas
# Out:
# [2.3313000000000024,
#  29.602600000000002,
#  19.023000000000003,
#  3.125200000000003,
#  4.7616,
#  0.5619999999999985,
#  9.225399999999999,
#  11.0045,
#  8.3703,
#  0.8052000000000024,
#  13.775200000000002,
#  7.958599999999992,
#  14.433799999999998,
#  33.584599999999995,
#  30.6826,
#  27.740600000000004,
#  1.6973999999999967,
#  43.6038]

# %% [markdown]
# ### Щербаков Игорь СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

def vector_list_lens(v):
    return np.sqrt((v.T)[0]**2+(v.T)[1]**2).T

def triangle_area(a,b,c):
    p=(a+b+c)/2
    return np.sqrt(p*(p-a)*(p-b)*(p-c))
def calculate_areas(vecs):
    v=np.array(vecs)
    a=vector_list_lens(v[1:-1]-v[:-2])
    b=vector_list_lens(v[2:]-v[1:-1])
    c=vector_list_lens(v[2:]-v[:-2])
    return triangle_area(a,b,c)
print(calculate_areas(vecs))
# Out:
# [ 1.16565 14.8013   9.5115   1.5626   2.3808   0.281    4.6127   5.50225
#   4.18515  0.4026   6.8876   3.9793   7.2169  16.7923  15.3413  13.8703
#   0.8487  21.8019 ]

# %% [markdown]
# ### Шомахов Идар СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np


vecs = np.array(vecs)

def ang(v1,v2):
    return np.arccos(( v1.dot(v2)) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
    
def area(v1,v2):
    return 0.5 * np.linalg.norm(v1) * np.linalg.norm(v2) * np.sin(ang(v1, v2))

for i in range(np.shape(vecs)[0] - 1):
    print(i, area(vecs[i], vecs[i + 1]))
# Out:
# 0 15.761449999999984
# 1 30.336650000000002
# 2 25.56190000000001
# 3 10.470849999999986
# 4 5.439200000000019
# 5 8.09060000000002
# 6 14.363800000000014
# 7 7.9728999999999965
# 8 0.7267000000000842
# 9 10.024050000000017
# 10 10.74835000000001
# 11 2.127150000000006
# 12 0.4670000000001141
# 13 10.774849999999994
# 14 18.687999999999995
# 15 19.47094999999998
# 16 20.973749999999995
# 17 19.5399
# 18 35.22305

# %% [markdown]
# ### Григорьев Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np


vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

def S(a):#площадь треугольника
    return abs(np.linalg.det([[a[0][0] - a[2][0], a[0][1] - a[2][1]],[a[1][0]-a[2][0],a[1][1] - a[2][1]]])) * 1/2 

def dot3(a, b, c):#матрица из трёх точек
    return np.vstack((a, b, c))

for i in range(len(vecs) - 2):
    print(S(dot3(vecs[i],vecs[i+1],vecs[i+2])))
# Out:
# 1.1656500000000012
# 14.801300000000001
# 9.511500000000002
# 1.5626000000000018
# 2.3807999999999994
# 0.28099999999999936
# 4.6126999999999985
# 5.502249999999999
# 4.18515
# 0.4026000000000013
# 6.887600000000002
# 3.9792999999999963
# 7.216900000000001
# 16.792299999999994
# 15.341300000000006
# 13.870300000000002
# 0.8486999999999982
# 21.801899999999996

# %% [markdown]
# ### Фомин Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vecs = np.array(vecs)

s = lambda vec1, vec2: 0.5 * np.linalg.norm(vec1) * np.linalg.norm(vec2) * np.sin(angle(vec1, vec2))
angle = lambda vec1, vec2: np.arccos(( vec1.dot(vec2)) / (np.linalg.norm(vec1) * np.linalg.norm(vec2)))

for i in range(np.shape(vecs)[0] - 1):
    print("Площадь {0} треугольника ->  {1}".format(i, s(vecs[i], vecs[i + 1])))
# Out:
# Площадь 0 треугольника ->  15.761449999999984
# Площадь 1 треугольника ->  30.336650000000002
# Площадь 2 треугольника ->  25.56190000000001
# Площадь 3 треугольника ->  10.470849999999986
# Площадь 4 треугольника ->  5.439200000000019
# Площадь 5 треугольника ->  8.09060000000002
# Площадь 6 треугольника ->  14.363800000000014
# Площадь 7 треугольника ->  7.9728999999999965
# Площадь 8 треугольника ->  0.7267000000000842
# Площадь 9 треугольника ->  10.024050000000017
# Площадь 10 треугольника ->  10.74835000000001
# Площадь 11 треугольника ->  2.127150000000006
# Площадь 12 треугольника ->  0.4670000000001141
# Площадь 13 треугольника ->  10.774849999999994
# Площадь 14 треугольника ->  18.687999999999995
# Площадь 15 треугольника ->  19.47094999999998
# Площадь 16 треугольника ->  20.973749999999995
# Площадь 17 треугольника ->  19.5399
# Площадь 18 треугольника ->  35.22305

# %% [markdown]
# ### Синицын Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

for i in range(len(vecs) - 2):
    s = np.array([[vecs[i][0]-vecs[i+2][0], vecs[i][1]-vecs[i+2][1]], [vecs[i+1][0] - vecs[i+2][0], vecs[i+1][1] - vecs[i+2][1]]])
    print(np.around(np.abs(np.linalg.det(s)*0.5), decimals = 3))
# Out:
# 1.166
# 14.801
# 9.512
# 1.563
# 2.381
# 0.281
# 4.613
# 5.502
# 4.185
# 0.403
# 6.888
# 3.979
# 7.217
# 16.792
# 15.341
# 13.87
# 0.849
# 21.802

# %% [markdown]
# ### Смирнов Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
np.set_printoptions(precision=2)

def area(a, b, c):
    return abs((b[0]-a[0]) * (c[1]-a[1]) - (c[0]-a[0]) * (b[1]-a[1])) / 2

print(np.array(list(map(lambda i: area(vecs[i], vecs[i+1], vecs[i+2]), range(len(vecs) - 2)))))
# Out:
# [ 1.17 14.8   9.51  1.56  2.38  0.28  4.61  5.5   4.19  0.4   6.89  3.98
#   7.22 16.79 15.34 13.87  0.85 21.8 ]

# %% [markdown]
# ### Расторгуева Мария СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

import numpy as np
def area(x, y):
    return 0.5*np.abs(np.dot(x,np.roll(y,1))-np.dot(y,np.roll(x,1)))
l = []
arr = np.array(vecs)
for i in range(arr.shape[0] - 2):
    l.append(area(arr[i:i+3].T[0], arr[i:i+3].T[1]))
for i in l:
    print (i)
# Out:
# 1.1656499999999994
# 14.801299999999998
# 9.511500000000005
# 1.5625999999999962
# 2.3808000000000007
# 0.2809999999999988
# 4.61269999999999
# 5.5022499999999965
# 4.18515
# 0.40260000000000673
# 6.887600000000006
# 3.979299999999988
# 7.216899999999995
# 16.792299999999997
# 15.341299999999997
# 13.870300000000007
# 0.8486999999999938
# 21.80189999999999

# %% [markdown]
# ### Гвасалия Метью СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

print(*list(map(lambda x: (1/2.)*np.linalg.norm(np.cross(np.array(vecs[vecs.index(x)+1]) - np.array(x),np.array(x) - np.array(vecs[vecs.index(x)-1]))),vecs[1:-1])), sep = '\n')
# Out:
# 1.1656499999999985
# 14.801300000000001
# 9.511500000000002
# 1.5626000000000015
# 2.3808
# 0.2809999999999995
# 4.612699999999999
# 5.502249999999998
# 4.18515
# 0.4026000000000012
# 6.887600000000001
# 3.9793000000000003
# 7.216900000000001
# 16.792299999999997
# 15.3413
# 13.870300000000002
# 0.8486999999999982
# 21.8019

# %% [markdown]
# ### Поддубный Михаил СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
#если речь идет о векторах, как написано в задании, то треугольник образует каждая последовательная пара векторов.
import numpy as np
print(
    list(
        map(
            lambda i:1/2*abs(np.cross(vecs[i],vecs[i+1])),
             range(0,len(vecs)-1)
            )
        )
)

#Если речь идет все-таки о ТОЧКАХ, как в 13 задании, то решение выглядит следующим образом.
import numpy as np
print(
    list(
        map(
            lambda i:(1/2)*abs(np.cross([vecs[i+1][0]-vecs[i][0],vecs[i+1][1]-vecs[i][1]],[vecs[i+2][0]-vecs[i][0],vecs[i+2][1]-vecs[i][1]])),
             range(0,len(vecs)-2)
            )
        )
)
# Out:
# [15.76145, 30.33665, 25.5619, 10.470849999999997, 5.4392, 8.090599999999997, 14.3638, 7.9729, 0.7267000000000001, 10.02405, 10.748349999999999, 2.1271499999999977, 0.4670000000000005, 10.774849999999999, 18.688, 19.470950000000002, 20.973749999999995, 19.5399, 35.22305]
# [1.1656499999999999, 14.801300000000001, 9.511500000000002, 1.5626000000000015, 2.3808000000000002, 0.28099999999999936, 4.612699999999999, 5.502249999999999, 4.18515, 0.4026000000000012, 6.8876, 3.979299999999997, 7.216899999999999, 16.792299999999997, 15.3413, 13.870300000000002, 0.8486999999999983, 21.801900000000003]

# %% [markdown]
# ### Миронов Никита СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Шубин Никита СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]
for i in range(len(vecs) - 2):
    vec1 = [vecs[i][0] - vecs[i+1][0], vecs[i][1] - vecs[i+1][1]] 
    vec2 = [vecs[i][0] - vecs[i+2][0], vecs[i][1] - vecs[i+2][1]]
    print(abs(np.dot(vec1, vec2)/2))
# Out:
# 7.407150000000001
# 13.107150000000004
# 1.6388999999999987
# 11.443850000000003
# 2.1635999999999997
# 1.7608000000000004
# 11.2855
# 1.9822499999999992
# 7.952300000000001
# 4.587
# 0.024400000000002198
# 4.3776
# 5.3937
# 5.055400000000001
# 23.765099999999997
# 7.093299999999998
# 0.9915999999999991
# 19.555500000000002

# %% [markdown]
# ### Щеглова Полина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
def Sq_np(p1, p2, p3):
    return abs(np.trapz([p1[1], p2[1], p3[1], p1[1]], [p1[0], p2[0], p3[0], p1[0]]))
print(list(map(Sq_np, vecs[:-2], vecs[1:-1], vecs[2:])))
# Out:
# [1.1656499999999976, 14.801299999999998, 9.511500000000005, 1.5625999999999998, 2.3808000000000007, 0.2809999999999988, 4.6127, 5.50225, 4.185150000000004, 0.4025999999999996, 6.8875999999999955, 3.979299999999991, 7.216900000000004, 16.792299999999997, 15.341300000000004, 13.8703, 0.8487000000000031, 21.80190000000001]

# %% [markdown]
# ### Мухамадиева Регина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
import numpy.linalg
vecs = np.array([[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]])
for i in range(len(vecs)-3):
    t = np.array([vecs[i]-vecs[i+2],vecs[i+1]-vecs[i+2]])
    print(np.absolute(np.linalg.det(t)/2))
# Out:
# 1.1656500000000012
# 14.801300000000001
# 9.511500000000002
# 1.5626000000000013
# 2.3807999999999994
# 0.2809999999999993
# 4.6126999999999985
# 5.502249999999999
# 4.18515
# 0.402600000000001
# 6.887600000000002
# 3.9792999999999963
# 7.216900000000001
# 16.792299999999994
# 15.341300000000006
# 13.870300000000002
# 0.8486999999999982

# %% [markdown]
# ### Астраханцев Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
v = np.array(vecs)
triangles = np.stack((v[:-2], v[1:-1], v[2:]), axis=1)
matrs = np.append(triangles, np.ones(v[:-2].shape[0] * 3).reshape(-1,3,1), axis=2)
np.abs(1/2 * np.linalg.det(matrs))
# Out:
# array([ 1.16565, 14.8013 ,  9.5115 ,  1.5626 ,  2.3808 ,  0.281  ,
#         4.6127 ,  5.50225,  4.18515,  0.4026 ,  6.8876 ,  3.9793 ,
#         7.2169 , 16.7923 , 15.3413 , 13.8703 ,  0.8487 , 21.8019 ])

# %% [markdown]
# ### Бесчастных Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
newArr = np.array(vecs)
for i in np.arange(0, newArr.shape[0] - 2):
    t = np.array([newArr[i] - newArr[i + 2], newArr[i + 1] - newArr[i + 2]])
    print(0.5 * abs(np.linalg.det(t)))
# Out:
# 1.1656500000000012
# 14.801300000000001
# 9.511500000000002
# 1.5626000000000018
# 2.3807999999999994
# 0.28099999999999936
# 4.6126999999999985
# 5.502249999999999
# 4.18515
# 0.4026000000000013
# 6.887600000000002
# 3.9792999999999963
# 7.216900000000001
# 16.792299999999994
# 15.341300000000006
# 13.870300000000002
# 0.8486999999999982
# 21.801899999999996

# %% [markdown]
# ### Музаффаров Руфат СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Гаварина Светлана СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

mas = np.stack([vecs[:-2], vecs[1:-1], vecs[2:]], axis=1) # разбиение на треугольники
vec_a = mas[:,0,:] - mas[:,1,:]
vec_b = mas[:,1,:] - mas[:,2,:]
1/2*abs(np.cross(vec_a, vec_b))
# Out:
# array([ 1.16565, 14.8013 ,  9.5115 ,  1.5626 ,  2.3808 ,  0.281  ,
#         4.6127 ,  5.50225,  4.18515,  0.4026 ,  6.8876 ,  3.9793 ,
#         7.2169 , 16.7923 , 15.3413 , 13.8703 ,  0.8487 , 21.8019 ])

# %% [markdown]
# ### Дундуков Семен СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Бень Таисия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np
triangles = np.stack( (vecs[:-2], vecs[1:-1],vecs[2:] ), axis=1)
v1 = triangles[:,0,:]-triangles[:,1,:]
v2 = triangles[:,1,:]-triangles[:,2,:]
1/2*abs(np.cross(v1,v2))
# Out:
# array([ 1.16565, 14.8013 ,  9.5115 ,  1.5626 ,  2.3808 ,  0.281  ,
#         4.6127 ,  5.50225,  4.18515,  0.4026 ,  6.8876 ,  3.9793 ,
#         7.2169 , 16.7923 , 15.3413 , 13.8703 ,  0.8487 , 21.8019 ])

# %% [markdown]
# ### Козликина Татьяна СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
import numpy as np

for i in range (len(vecs) - 2):
    v0 = np.array(vecs[i]) #Даны координаты точек
    v1 = np.array(vecs[i+1])
    v2 = np.array(vecs[i+2])
    print('Площадь %s-го треугольника = %f'%(i+1, np.abs(np.dot(v0-v1, v1-v2)/2 )))
# Out:
# Площадь 1-го треугольника = 15.006200
# Площадь 2-го треугольника = 16.705100
# Площадь 3-го треугольника = 15.070300
# Площадь 4-го треугольника = 7.562600
# Площадь 5-го треугольника = 0.974000
# Площадь 6-го треугольника = 3.869700
# Площадь 7-го треугольника = 4.147400
# Площадь 8-го треугольника = 3.408250
# Площадь 9-го треугольника = 0.181050
# Площадь 10-го треугольника = 2.328900
# Площадь 11-го треугольника = 2.449300
# Площадь 12-го треугольника = 25.980100
# Площадь 13-го треугольника = 26.584100
# Площадь 14-го треугольника = 18.673500
# Площадь 15-го треугольника = 2.813500
# Площадь 16-го треугольника = 2.059600
# Площадь 17-го треугольника = 20.490900
# Площадь 18-го треугольника = 0.023100

# %% [markdown]
# ### Апресян Тигран СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Долотов Фёдор СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %% [markdown]
# ### Попов Юрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# в матрице vecs - координаты x, y векторов в двумерном пространстве
# каждая последовательная тройка точек (i, i+1, i+2) образует треугольник
# используя только возможности NumPy рассчитать площади таких треугольников
vecs = [[6.44, 5.05],
        [3.59, 7.71],
        [8.81, 2.02],
        [8.71, 7.8 ],
        [5.51, 2.53],
        [6.35, 4.89],
        [7.88, 3.52],
        [4.89, 5.83],
        [1.66, 5.24],
        [3.1 , 8.91],
        [5.11, 8.22],
        [7.06, 7.15],
        [2.15, 2.78],
        [7.25, 8.94],
        [1.62, 4.97],
        [8.86, 4.11],
        [8.59, 8.38],
        [2.18, 7.01],
        [8.24, 8.57],
        [9.97, 1.82]]

# %%
# Задание_16
import numpy as np
import numpy as np


for i in range (len(vecs) - 2):
    v0 = np.array(vecs[i])
    v1 = np.array(vecs[i+1])
    v2 = np.array(vecs[i+2])
    print('Площадь %s-го треугольника = %f'%(i+1, np.abs(np.dot(v0-v1, v1-v2)/2 )))
# Out:
# Площадь 1-го треугольника = 15.006200
# Площадь 2-го треугольника = 16.705100
# Площадь 3-го треугольника = 15.070300
# Площадь 4-го треугольника = 7.562600
# Площадь 5-го треугольника = 0.974000
# Площадь 6-го треугольника = 3.869700
# Площадь 7-го треугольника = 4.147400
# Площадь 8-го треугольника = 3.408250
# Площадь 9-го треугольника = 0.181050
# Площадь 10-го треугольника = 2.328900
# Площадь 11-го треугольника = 2.449300
# Площадь 12-го треугольника = 25.980100
# Площадь 13-го треугольника = 26.584100
# Площадь 14-го треугольника = 18.673500
# Площадь 15-го треугольника = 2.813500
# Площадь 16-го треугольника = 2.059600
# Площадь 17-го треугольника = 20.490900
# Площадь 18-го треугольника = 0.023100
