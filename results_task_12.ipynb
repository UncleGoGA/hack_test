# %% [markdown]
# -----
# #### Задание 12

# %% [markdown]
# ### Федоров Сергей СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''


# def coun(c):
    # lambda(c,glass: )
    # for t in glass:
    #     t.count(glass)
    # return reduce(lambda x,y: x + y,map(lambda glas: c.count(glas),glas)) 

from functools import reduce

glas = ['а','е','ё','и','о','у','ы','э','ю','я']

x = list(map(str, s.replace('\n',' ').replace('"',' ').replace('?',' ').replace('!',' ').replace('.',' ').replace(',',' ').replace('-',' ').lower().split()))
new_list = list(map(lambda glas,slovo: slovo.count(glas) ,glas,list(x)))

cisla = list(map(lambda c: reduce(lambda x,y: x + y,map(lambda glas: c.count(glas),glas))  ,x   )   )
print(list(zip(x,cisla)))
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным:', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссальн
# ...

# %% [markdown]
# ### Алексеев Кирилл СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

s = s.lower()

glasLetters = ['а', 'е', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']

s = " ".join(s.split("\n"))
s = " ".join(s.split())
print(s)
i = 0
p = "а"
letters = []
while i < 32:
    letters.append(p)
    p = chr(ord(p)+1)
    i = i + 1
    

word = "false"
ind = 0
k = 0
listSym = []
listGlas = []
for t in s:
    if t in letters:
        if word == "false":
            word = "true"
            ind = k
    elif word == "true":
        word = "false"
        ss = s[ind : k]
        sk = ""
        for p in ss:
            if p in glasLetters:
                sk = sk + p    
        listGlas.append(sk)
        listSym.append(ss)
        ind = k + 1
    k = k + 1 
listGlas = list(map(len, listGlas))
col = []
col = list(zip(listSym, listGlas))
print(col)

# %% [markdown]
# ### Анчугов Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
import functools as ft
reg = "аеёиоуыэюя"
words = list(filter(lambda item: item != "", s.replace("\n", " ").lower().split(" ")))
count = list(
    map(lambda word: 
        ft.reduce(lambda x,y: x+y,list(
            map(
                lambda symbol: word.count(symbol), reg)
            )), 
        words
       )
)
list(zip(words,count))
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны,', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба,', 2),
#  ('изгнал', 2),
#  ('ночь.', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть,', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным:', 3),
#  ('действительно,', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое.', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('-', 0),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы.', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток,', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
# ...

# %% [markdown]
# ### Акинина Алёна СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''
from functools import reduce
list(zip(s.lower().split(),list(map(lambda x: reduce(lambda i,j : i+j, list(map(lambda k : x.count(k), ['а','о','и','е','э','ы','у','ю','я']))), s.lower().split()))))
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны,', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба,', 2),
#  ('изгнал', 2),
#  ('ночь.', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть,', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным:', 3),
#  ('действительно,', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое.', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('-', 0),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы.', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток,', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
# ...

# %% [markdown]
# ### Лисьев Александр СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s1 = s.lower().split()
list( zip(s1, map(lambda x: sum(map(x.count, ["а", "о", "у", "е", "и", "ы"])), s1) ) )
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 1),
#  ('раз', 1),
#  ('ярче', 1),
#  ('полной', 2),
#  ('луны,', 2),
#  ('люцифер', 2),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба,', 2),
#  ('изгнал', 2),
#  ('ночь.', 1),
#  ('несмотря', 2),
#  ('на', 1),
#  ('некоторую', 4),
#  ('зловещесть,', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным:', 3),
#  ('действительно,', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 0),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое.', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 3),
#  ('станут', 2),
#  ('ясны', 1),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('-', 0),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы.', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 0),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 1),
#  ('суток,', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
# ...

# %% [markdown]
# ### Чердак Александр СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %% [markdown]
# ### Шелепова Алена СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

s = s.lower().replace('-','').replace(' ""','').replace('\n',' ')

# %%
gl = list("аоиеёэыуюя")
print(list(zip(list(map(lambda x: x.replace(',','').replace('.','').replace('?',''), s.split())),\
               list(map(lambda x : sum(x.count(c) for c in gl), s.split())))))
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным:', 3), ('действительно', 4), ('"светоносный"', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссал
# ...

# %% [markdown]
# ### Шнейдер Алиса СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce


list(
    zip(
        reduce(lambda s, r:s.replace(r, ''), '—-,.«»', s).split(), list(map(lambda word: sum([word.count(letter) for letter in 'уеыаоэёяию']), reduce(lambda s, r:s.replace(r, ''), '—-,.«»', s).split()))))
# Out:
# [('Будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('Луны', 2),
#  ('Люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба', 2),
#  ('изгнал', 2),
#  ('ночь', 1),
#  ('Несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным:', 3),
#  ('действительно', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое', 3),
#  ('А', 0),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы', 4),
#  ('Уход', 1),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
#  ('странах', 2),
# ...

# %% [markdown]
# ### Зайцева Анастасия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce
a = s.lower().split()
b = ['а','о','и','е','э','ы','у','ю','я']
kol = list(map(lambda x: reduce(lambda i,j: i+j, list(map(lambda k: x.count(k), b))), a))
list(zip(a,kol))
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны,', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба,', 2),
#  ('изгнал', 2),
#  ('ночь.', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть,', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным:', 3),
#  ('действительно,', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое.', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('-', 0),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы.', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток,', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
# ...

# %% [markdown]
# ### Полуяктов Анатолий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''
glasn=['а', 'у', 'о', 'ы', 'и', 'э', 'я', 'ю', 'ё', 'е']
s = re.sub(r'[^\w\s]','',s)
s=s.strip()
s=s.replace('\n', ' ')
s=s.lower()
s=s.split()
a=dict()
kolvo=(list(map(lambda x:sum(list(map(lambda s:  s in glasn,x))),s)))
list(zip(s,kolvo))
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба', 2),
#  ('изгнал', 2),
#  ('ночь', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным', 3),
#  ('действительно', 4),
#  ('светоносный', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
#  ('странах', 2),
# ...

# %% [markdown]
# ### Фомин Андрей СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from collections import Counter
vowels = "ёуеыаоэяию"


def count_vowels(txt):
    c = Counter(txt)
    return sum(c[v] for v in vowels)


print(dict(zip(s.replace('?', '').replace(',', '').replace('.', '').replace(':', '').replace('!', '').replace('-', '').\
            replace('\"', '').lower().split(),list(map(lambda x: count_vowels(x), s.replace('?', '').replace(',','')\
            .replace('.','').replace(':','').replace('!', '').replace('-','').replace('\"', '').lower().split())))))
# Out:
# {'будучи': 3, 'в': 0, 'пятьдесят': 3, 'раз': 1, 'ярче': 2, 'полной': 2, 'луны': 2, 'люцифер': 3, 'изменил': 3, 'картину': 3, 'земного': 3, 'неба': 2, 'изгнал': 2, 'ночь': 1, 'несмотря': 3, 'на': 1, 'некоторую': 5, 'зловещесть': 3, 'название': 4, 'оказалось': 4, 'удачным': 3, 'действительно': 4, 'светоносный': 4, 'дал': 1, 'людям': 2, 'и': 1, 'доброе': 3, 'плохое': 3, 'а': 1, 'окончательные': 6, 'результаты': 4, 'его': 2, 'появления': 5, 'станут': 2, 'ясны': 2, 'лишь': 1, 'через': 2, 'сотни': 2, 'лет': 1, 'или': 2, 'миллионы': 4, 'уход': 2, 'ночи': 2, 'увеличил': 4, 'для': 1, 'человечества': 5, 'активное': 4, 'время': 2, 'суток': 2, 'особенно': 4, 'слаборазвитых': 5, 'странах': 2, 'потребность': 3, 'искусственном': 4, 'освещении': 5, 'значительно': 4, 'сократилась': 4, 'это': 2, 'привело': 3, 'к': 0, 'колоссальной': 4, 'экономии': 5, 'электроэнергии': 7, 'небесах': 3, 'зажглась': 2, 'мощнейшая': 4, 'лампа': 2, 'озаряющая': 6, 'полмира': 3, 'да': 1, 'днем': 1, 'соперничал': 4, 'с': 0, 
# ...

# %% [markdown]
# ### Марипова Жасмин СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
l = s.split(' ') 
l = [a for a in l if a]
list(map(lambda x: print(x.strip('\n'), sum(x.lower().count(a) for a in 'ёуеыаоэяиюaeiou')), l))
# Out:
# Будучи 3
# в 0
# пятьдесят 3
# раз 1
# ярче 2
# полной 2
# Луны, 2
# Люцифер 3
# изменил 3
# картину
# земного 6
# неба, 2
# изгнал 2
# ночь. 1
# Несмотря 3
# на 1
# некоторую 5
# зловещесть, 3
# название
# оказалось 8
# удачным: 3
# действительно, 4
# "светоносный" 4
# дал 1
# людям 2
# и 1
# доброе 3
# и
# плохое. 4
# А 1
# окончательные 6
# результаты 4
# его 2
# появления 5
# станут 2
# ясны 2
# лишь 1
# через
# сотни 4
# лет 1
# - 0
# или 2
# через 2
# миллионы. 4
# Уход 2
# ночи 2
# увеличил 4
# для 1
# человечества 5
# активное 4
# время 2
# суток, 2
# особенно
# в 4
# слаборазвитых 5
# странах. 2
# Потребность 3
# в 0
# искусственном 4
# освещении
# значительно 9
# сократилась, 4
# и 1
# это 2
# привело 3
# к 0
# колоссальной 4
# экономии
# электроэнергии. 12
# В 0
# небесах 3
# зажглась 2
# мощнейшая 4
# лампа, 2
# озаряющая 6
# полмира.
# Да 4
# и 1
# днем 1
# Люцифер 3
# соперничал 4
# с 0
# Солнцем: 2
# предметы 3
# отбрасывали 5
# отчетливые
# двойные 8
# тени. 2
# ...

# %% [markdown]
# ### Зоричев Борис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

text = s.replace('\n', ' ').replace('-','').replace('"','').replace('.','').replace(':','').replace('!','').replace('?','').lower().split()
print(list(map(lambda word: (word, sum(map(lambda letter:word.count(letter),"аеиоуыэюя"))), text)))
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны,', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба,', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть,', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно,', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток,', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась,', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колос
# ...

# %% [markdown]
# ### Сербаев Вадим СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

s = s.lower()
s = s.split()

import re

def count_vowels(string):
    vowels = re.findall('[аеёиоуыэюя]', string, re.IGNORECASE)
    return len(vowels)
N = []
for i in range(len(s)): #как тут сделать через map так и не понял
    N.append(count_vowels(s[i]))
    
F = list(zip(s, N))
print(F)
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны,', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба,', 2), ('изгнал', 2), ('ночь.', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть,', 3), ('название', 4), ('оказалось', 4), ('удачным:', 3), ('действительно,', 4), ('"светоносный"', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое.', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('-', 0), ('или', 2), ('через', 2), ('миллионы.', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток,', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах.', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась,', 4), ('и', 1), ('это', 2), ('привело', 3), 
# ...

# %% [markdown]
# ### Булгаков Виталий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
text = s.replace('\n', ' ').replace('-','').replace('"','').replace('.','').replace(':','').replace('!','').replace('?','').lower().split()
word = list(map(lambda word: (word, sum(map(lambda letter:word.count(letter),"аеиоуыэюя"))), text))
word
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны,', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба,', 2),
#  ('изгнал', 2),
#  ('ночь', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть,', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным', 3),
#  ('действительно,', 4),
#  ('светоносный', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток,', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
#  ('странах', 2),
# ...

# %% [markdown]
# ### Андреева Влада СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce

def countvowel(word):
    vowel = ['а', 'е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']
    print('(', end='')
    print(word, end=', ')
    print(reduce(lambda x, y: x + word.count(str(y)), vowel, 0), end='')
    print(')')
    
s = s.lower()
s = reduce(lambda s, r:s.replace(r, ' '), '—-,.«»!?:"', s)
a = list(map(countvowel, s.split()))
# Out:
# (будучи, 3)
# (в, 0)
# (пятьдесят, 3)
# (раз, 1)
# (ярче, 2)
# (полной, 2)
# (луны, 2)
# (люцифер, 3)
# (изменил, 3)
# (картину, 3)
# (земного, 3)
# (неба, 2)
# (изгнал, 2)
# (ночь, 1)
# (несмотря, 3)
# (на, 1)
# (некоторую, 5)
# (зловещесть, 3)
# (название, 4)
# (оказалось, 4)
# (удачным, 3)
# (действительно, 4)
# (светоносный, 4)
# (дал, 1)
# (людям, 2)
# (и, 1)
# (доброе, 3)
# (и, 1)
# (плохое, 3)
# (а, 1)
# (окончательные, 6)
# (результаты, 4)
# (его, 2)
# (появления, 5)
# (станут, 2)
# (ясны, 2)
# (лишь, 1)
# (через, 2)
# (сотни, 2)
# (лет, 1)
# (или, 2)
# (через, 2)
# (миллионы, 4)
# (уход, 2)
# (ночи, 2)
# (увеличил, 4)
# (для, 1)
# (человечества, 5)
# (активное, 4)
# (время, 2)
# (суток, 2)
# (особенно, 4)
# (в, 0)
# (слаборазвитых, 5)
# (странах, 2)
# (потребность, 3)
# (в, 0)
# (искусственном, 4)
# (освещении, 5)
# (значительно, 4)
# (сократилась, 4)
# (и, 1)
# (это, 2)
# (привело, 3)
# (к, 0)
# (колоссальной, 4)
# (экономии, 5)
# (электроэнергии, 7)
# (в, 0)
# ...

# %% [markdown]
# ### Клопов Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce
data=s.lower().replace('.','').replace('?','').replace(';','').replace(':','').replace('-','').replace('"','').replace(',','').replace('\n',' ').strip().replace('  ',' ').replace('  ',' ').replace('  ',' ').split(' ')
glas=lambda x: x in ['а','о','е','ё','и','э','ы','у','я','ю']
count=lambda a,x: a+glas(x)
list(map(lambda y: print((y,reduce(count,y,0))),data))
# Out:
# ('будучи', 3)
# ('в', 0)
# ('пятьдесят', 3)
# ('раз', 1)
# ('ярче', 2)
# ('полной', 2)
# ('луны', 2)
# ('люцифер', 3)
# ('изменил', 3)
# ('картину', 3)
# ('земного', 3)
# ('неба', 2)
# ('изгнал', 2)
# ('ночь', 1)
# ('несмотря', 3)
# ('на', 1)
# ('некоторую', 5)
# ('зловещесть', 3)
# ('название', 4)
# ('оказалось', 4)
# ('удачным', 3)
# ('действительно', 4)
# ('светоносный', 4)
# ('дал', 1)
# ('людям', 2)
# ('и', 1)
# ('доброе', 3)
# ('и', 1)
# ('плохое', 3)
# ('а', 1)
# ('окончательные', 6)
# ('результаты', 4)
# ('его', 2)
# ('появления', 5)
# ('станут', 2)
# ('ясны', 2)
# ('лишь', 1)
# ('через', 2)
# ('сотни', 2)
# ('лет', 1)
# ('или', 2)
# ('через', 2)
# ('миллионы', 4)
# ('уход', 2)
# ('ночи', 2)
# ('увеличил', 4)
# ('для', 1)
# ('человечества', 5)
# ('активное', 4)
# ('время', 2)
# ('суток', 2)
# ('особенно', 4)
# ('в', 0)
# ('слаборазвитых', 5)
# ('странах', 2)
# ('потребность', 3)
# ('в', 0)
# ('искусственном', 4)
# ('освещении', 5)
# ('значительно', 4)
# ('сократилась', 4)
# ...

# %% [markdown]
# ### Сарахан Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
def getWords(p):
    return p.lower().strip().replace('\\', ' ').replace('\n', ' ').replace('  ', ' ').replace(',',' ').replace(';', '').replace('.', '').replace('?', '').replace('-', '').replace(':', '').replace('\"', '').replace('  ', ' ').replace('  ', ' ').split(' ')

# %%
isVowel = lambda x: x == 'а' or x == 'о' or x == 'и' or x == 'е' or x == 'ё' or x == 'э' or x == 'ы' or x == 'у' or x == 'ю' or x == 'я'

# %%
result = list(  map(  (lambda y: print(  (y,  len(list(filter(isVowel, y)))   )  )  ), getWords(s)  )  )
# Out:
# ('будучи', 3)
# ('в', 0)
# ('пятьдесят', 3)
# ('раз', 1)
# ('ярче', 2)
# ('полной', 2)
# ('луны', 2)
# ('люцифер', 3)
# ('изменил', 3)
# ('картину', 3)
# ('земного', 3)
# ('неба', 2)
# ('изгнал', 2)
# ('ночь', 1)
# ('несмотря', 3)
# ('на', 1)
# ('некоторую', 5)
# ('зловещесть', 3)
# ('название', 4)
# ('оказалось', 4)
# ('удачным', 3)
# ('действительно', 4)
# ('светоносный', 4)
# ('дал', 1)
# ('людям', 2)
# ('и', 1)
# ('доброе', 3)
# ('и', 1)
# ('плохое', 3)
# ('а', 1)
# ('окончательные', 6)
# ('результаты', 4)
# ('его', 2)
# ('появления', 5)
# ('станут', 2)
# ('ясны', 2)
# ('лишь', 1)
# ('через', 2)
# ('сотни', 2)
# ('лет', 1)
# ('или', 2)
# ('через', 2)
# ('миллионы', 4)
# ('уход', 2)
# ('ночи', 2)
# ('увеличил', 4)
# ('для', 1)
# ('человечества', 5)
# ('активное', 4)
# ('время', 2)
# ('суток', 2)
# ('особенно', 4)
# ('в', 0)
# ('слаборазвитых', 5)
# ('странах', 2)
# ('потребность', 3)
# ('в', 0)
# ('искусственном', 4)
# ('освещении', 5)
# ('значительно', 4)
# ('сократилась', 4)
# ...

# %% [markdown]
# ### Старостин Данила СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
vowels = ['а', 'е', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']


def count_vowels(word):
    return len(list(filter(lambda char: char in vowels, word)))

def count_vowels_per_word(text):
    return map(lambda word: (word, count_vowels(word)), text.split())


s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

print(list(count_vowels_per_word(s)))
# Out:
# [('Будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('Луны,', 2), ('Люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба,', 2), ('изгнал', 2), ('ночь.', 1), ('Несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть,', 3), ('название', 4), ('оказалось', 4), ('удачным:', 3), ('действительно,', 4), ('"светоносный"', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое.', 3), ('А', 0), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('-', 0), ('или', 2), ('через', 2), ('миллионы.', 4), ('Уход', 1), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток,', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах.', 2), ('Потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась,', 4), ('и', 1), ('это', 2), ('привело', 3), 
# ...

# %% [markdown]
# ### Стрекнев Денис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
import re
import itertools
p=[]
p3=[]
p4=[]
p=re.split(r'([.?])',s)
p.remove('')
p1=list(map(lambda x: x.replace('\n', ' '), p))
p2=list(itertools.chain(*list(map(lambda x: x.split(' '),p1))))
list(map(lambda x: p3.append(x.lower()) if (x!='') and (x!='-') and (x!='.') and (x!='?') else None, p2))
for i in p3:
    p5=list(map(lambda x: 1 if (x=='а') or (x=='о') or (x=='и') or (x=='е') or (x=='э') or (x=='ы') or (x=='у') or (x=='ю') or (x=='я') else 0, i))
    p4.append(sum(p5))
inf=list(zip(p3,p4))
inf
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны,', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба,', 2),
#  ('изгнал', 2),
#  ('ночь', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть,', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным:', 3),
#  ('действительно,', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток,', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
#  ('странах', 2),
# ...

# %% [markdown]
# ### Дородный Дмитрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
print(*[(i, sum(list(map(lambda x: (x in ('а', 'е', 'о', 'и', 'у', 'ы', 'ю', 'я'))*1, i)))) for i in s.replace('-', '').lower().split()])
# Out:
# ('будучи', 3) ('в', 0) ('пятьдесят', 3) ('раз', 1) ('ярче', 2) ('полной', 2) ('луны,', 2) ('люцифер', 3) ('изменил', 3) ('картину', 3) ('земного', 3) ('неба,', 2) ('изгнал', 2) ('ночь.', 1) ('несмотря', 3) ('на', 1) ('некоторую', 5) ('зловещесть,', 3) ('название', 4) ('оказалось', 4) ('удачным:', 3) ('действительно,', 4) ('"светоносный"', 4) ('дал', 1) ('людям', 2) ('и', 1) ('доброе', 3) ('и', 1) ('плохое.', 3) ('а', 1) ('окончательные', 6) ('результаты', 4) ('его', 2) ('появления', 5) ('станут', 2) ('ясны', 2) ('лишь', 1) ('через', 2) ('сотни', 2) ('лет', 1) ('или', 2) ('через', 2) ('миллионы.', 4) ('уход', 2) ('ночи', 2) ('увеличил', 4) ('для', 1) ('человечества', 5) ('активное', 4) ('время', 2) ('суток,', 2) ('особенно', 4) ('в', 0) ('слаборазвитых', 5) ('странах.', 2) ('потребность', 3) ('в', 0) ('искусственном', 4) ('освещении', 5) ('значительно', 4) ('сократилась,', 4) ('и', 1) ('это', 1) ('привело', 3) ('к', 0) ('колоссальной', 4) ('экономии', 4) ('электроэнергии.', 5) ('в', 0
# ...

# %% [markdown]
# ### Шемякин Дмитрий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

import re

vowels = ['а','е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']

s = re.sub(r'[^\w\s]','',s)
s_lower = s.lower().split()

d = dict()
l = list(map(lambda x: sum(list(map(lambda y: y in vowels, x))), s_lower))
d = list(zip(s_lower,l))
print(d)
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Никитина Елизавета СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

def countw(word):
    char_list = list('уеыаоэяиюeyuioa')
    return sum([ word.count(ch) for ch in char_list ])
words = [a.lower().strip(',.') for a in s.split()]
result = {word: countw(word) for word in words}
print(result)
# Out:
# {'будучи': 3, 'в': 0, 'пятьдесят': 3, 'раз': 1, 'ярче': 2, 'полной': 2, 'луны': 2, 'люцифер': 3, 'изменил': 3, 'картину': 3, 'земного': 3, 'неба': 2, 'изгнал': 2, 'ночь': 1, 'несмотря': 3, 'на': 1, 'некоторую': 5, 'зловещесть': 3, 'название': 4, 'оказалось': 4, 'удачным:': 3, 'действительно': 4, '"светоносный"': 4, 'дал': 1, 'людям': 2, 'и': 1, 'доброе': 3, 'плохое': 3, 'а': 1, 'окончательные': 6, 'результаты': 4, 'его': 2, 'появления': 5, 'станут': 2, 'ясны': 2, 'лишь': 1, 'через': 2, 'сотни': 2, 'лет': 1, '-': 0, 'или': 2, 'миллионы': 4, 'уход': 2, 'ночи': 2, 'увеличил': 4, 'для': 1, 'человечества': 5, 'активное': 4, 'время': 2, 'суток': 2, 'особенно': 4, 'слаборазвитых': 5, 'странах': 2, 'потребность': 3, 'искусственном': 4, 'освещении': 5, 'значительно': 4, 'сократилась': 4, 'это': 2, 'привело': 3, 'к': 0, 'колоссальной': 4, 'экономии': 5, 'электроэнергии': 7, 'небесах': 3, 'зажглась': 2, 'мощнейшая': 4, 'лампа': 2, 'озаряющая': 6, 'полмира': 3, 'да': 1, 'днем': 1, 'соперничал': 
# ...

# %% [markdown]
# ### Семенов Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce
t=list(filter(lambda x:x!='',reduce(lambda s, r:s.replace(r, ' '), '—,.«»-?:\n;""', s).split(' ')))
def f(t):
    return reduce(lambda x,r:x+t.lower().count(r),'аеёиоуыэюя',0)
print(list(zip(t, map(f,t))))
# Out:
# [('Будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('Луны', 2), ('Люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('Несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('А', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('Уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('Потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Шамрин Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce
glasn = list('АЕЁИОУЫЭЮЯ'.lower())
glasn.insert(0,0)
s = s.lower().replace('?', ' ').replace('!', ' ').replace(',',' ').replace('-',' ').replace('\n',' ').replace('.',' ').replace(':', ' ').split(' ')
list(map(lambda x: print(x, reduce(lambda y,z: y + int(list(x).count(z)), glasn)) if len(x) > 0 else False, s))
# Out:
# будучи 3
# в 0
# пятьдесят 3
# раз 1
# ярче 2
# полной 2
# луны 2
# люцифер 3
# изменил 3
# картину 3
# земного 3
# неба 2
# изгнал 2
# ночь 1
# несмотря 3
# на 1
# некоторую 5
# зловещесть 3
# название 4
# оказалось 4
# удачным 3
# действительно 4
# "светоносный" 4
# дал 1
# людям 2
# и 1
# доброе 3
# и 1
# плохое 3
# а 1
# окончательные 6
# результаты 4
# его 2
# появления 5
# станут 2
# ясны 2
# лишь 1
# через 2
# сотни 2
# лет 1
# или 2
# через 2
# миллионы 4
# уход 2
# ночи 2
# увеличил 4
# для 1
# человечества 5
# активное 4
# время 2
# суток 2
# особенно 4
# в 0
# слаборазвитых 5
# странах 2
# потребность 3
# в 0
# искусственном 4
# освещении 5
# значительно 4
# сократилась 4
# и 1
# это 2
# привело 3
# к 0
# колоссальной 4
# экономии 5
# электроэнергии 7
# в 0
# небесах 3
# зажглась 2
# мощнейшая 4
# лампа 2
# озаряющая 6
# полмира 3
# да 1
# и 1
# днем 1
# люцифер 3
# соперничал 4
# с 0
# солнцем 2
# предметы 3
# отбрасывали 5
# отчетливые 5
# двойные 3
# тени 2
# фермеры 3
# ...

# %% [markdown]
# ### Щербаков Игорь СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
#В задании ничего не говорится о повторах слов
#Выполнено для всего текста (с повторами слов в парах)

import re
def vowels_in_words(s, vowels='[ёуеыаоэяию]'):
    s=(re.sub('[!?.:;,\"\n]',' ',s.lower()).replace(' - ', ' '))
    words=s.split()
    return zip(words,map(lambda x: len(re.findall(vowels,x)), words))
print(list(vowels_in_words(s)))
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Шомахов Идар СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

l = s.split(' ') 
l = [a for a in l if a]
list(map(lambda x: print(x.strip('\n'), sum(x.lower().count(a) for a in 'ёуеыаоэяиюaeiou')), l))
# Out:
# Будучи 3
# в 0
# пятьдесят 3
# раз 1
# ярче 2
# полной 2
# Луны, 2
# Люцифер 3
# изменил 3
# картину
# земного 6
# неба, 2
# изгнал 2
# ночь. 1
# Несмотря 3
# на 1
# некоторую 5
# зловещесть, 3
# название
# оказалось 8
# удачным: 3
# действительно, 4
# "светоносный" 4
# дал 1
# людям 2
# и 1
# доброе 3
# и
# плохое. 4
# А 1
# окончательные 6
# результаты 4
# его 2
# появления 5
# станут 2
# ясны 2
# лишь 1
# через
# сотни 4
# лет 1
# - 0
# или 2
# через 2
# миллионы. 4
# Уход 2
# ночи 2
# увеличил 4
# для 1
# человечества 5
# активное 4
# время 2
# суток, 2
# особенно
# в 4
# слаборазвитых 5
# странах. 2
# Потребность 3
# в 0
# искусственном 4
# освещении
# значительно 9
# сократилась, 4
# и 1
# это 2
# привело 3
# к 0
# колоссальной 4
# экономии
# электроэнергии. 12
# В 0
# небесах 3
# зажглась 2
# мощнейшая 4
# лампа, 2
# озаряющая 6
# полмира.
# Да 4
# и 1
# днем 1
# Люцифер 3
# соперничал 4
# с 0
# Солнцем: 2
# предметы 3
# отбрасывали 5
# отчетливые
# двойные 8
# тени. 2
# ...

# %% [markdown]
# ### Григорьев Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

al = 'аоиеёэыуюя'
words = reduce(lambda s, p: s.replace(p,' '),':;!?,-".',s.lower()).split()#получение списка слов из строки s

print(list(map(lambda w: (w, reduce(lambda n, l: n + w.count(l), al, n)), words)))#подсчёт гласных(строка al) в каждом слове из words
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Фомин Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
l = s.split(' ') 
l = [p for p in l if p]
list(map(lambda x: print(x.strip('\n'), sum(x.lower().count(p) for p in 'яэиюeауёоыouiea')), l))
# Out:
# Будучи 3
# в 0
# пятьдесят 2
# раз 1
# ярче 1
# полной 2
# Луны, 2
# Люцифер 2
# изменил 2
# картину
# земного 5
# неба, 1
# изгнал 2
# ночь. 1
# Несмотря 2
# на 1
# некоторую 4
# зловещесть, 1
# название
# оказалось 7
# удачным: 3
# действительно, 2
# "светоносный" 3
# дал 1
# людям 2
# и 1
# доброе 2
# и
# плохое. 3
# А 1
# окончательные 4
# результаты 3
# его 1
# появления 4
# станут 2
# ясны 2
# лишь 1
# через
# сотни 2
# лет 0
# - 0
# или 2
# через 0
# миллионы. 4
# Уход 2
# ночи 2
# увеличил 3
# для 1
# человечества 2
# активное 3
# время 1
# суток, 2
# особенно
# в 3
# слаборазвитых 5
# странах. 2
# Потребность 2
# в 0
# искусственном 3
# освещении
# значительно 6
# сократилась, 4
# и 1
# это 2
# привело 2
# к 0
# колоссальной 4
# экономии
# электроэнергии. 10
# В 0
# небесах 1
# зажглась 2
# мощнейшая 3
# лампа, 2
# озаряющая 6
# полмира.
# Да 4
# и 1
# днем 0
# Люцифер 2
# соперничал 3
# с 0
# Солнцем: 1
# предметы 1
# отбрасывали 5
# отчетливые
# двойные 5
# тени. 1
# ...

# %% [markdown]
# ### Синицын Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
print(list(zip(list(map(lambda word: len(list(filter(lambda x: x in "аеёиоуыэюя", word))), s.lower().split())), s.lower().split())))
# Out:
# [(3, 'будучи'), (0, 'в'), (3, 'пятьдесят'), (1, 'раз'), (2, 'ярче'), (2, 'полной'), (2, 'луны,'), (3, 'люцифер'), (3, 'изменил'), (3, 'картину'), (3, 'земного'), (2, 'неба,'), (2, 'изгнал'), (1, 'ночь.'), (3, 'несмотря'), (1, 'на'), (5, 'некоторую'), (3, 'зловещесть,'), (4, 'название'), (4, 'оказалось'), (3, 'удачным:'), (4, 'действительно,'), (4, '"светоносный"'), (1, 'дал'), (2, 'людям'), (1, 'и'), (3, 'доброе'), (1, 'и'), (3, 'плохое.'), (1, 'а'), (6, 'окончательные'), (4, 'результаты'), (2, 'его'), (5, 'появления'), (2, 'станут'), (2, 'ясны'), (1, 'лишь'), (2, 'через'), (2, 'сотни'), (1, 'лет'), (0, '-'), (2, 'или'), (2, 'через'), (4, 'миллионы.'), (2, 'уход'), (2, 'ночи'), (4, 'увеличил'), (1, 'для'), (5, 'человечества'), (4, 'активное'), (2, 'время'), (2, 'суток,'), (4, 'особенно'), (0, 'в'), (5, 'слаборазвитых'), (2, 'странах.'), (3, 'потребность'), (0, 'в'), (4, 'искусственном'), (5, 'освещении'), (4, 'значительно'), (4, 'сократилась,'), (1, 'и'), (2, 'это'), (3, 'привело'), 
# ...

# %% [markdown]
# ### Смирнов Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce

words = reduce(lambda word, char: word.replace(char, ''), ',.-!?:;"', s.replace('\n', ' ')).lower().split()
vowels = map(lambda i: len(reduce(lambda word, letter: word.replace(letter, ''), 'бвгджзйклмнпрстфхцчшщъь', i)), words)

print(*list(zip(words, vowels)))
# Out:
# ('будучи', 3) ('в', 0) ('пятьдесят', 3) ('раз', 1) ('ярче', 2) ('полной', 2) ('луны', 2) ('люцифер', 3) ('изменил', 3) ('картину', 3) ('земного', 3) ('неба', 2) ('изгнал', 2) ('ночь', 1) ('несмотря', 3) ('на', 1) ('некоторую', 5) ('зловещесть', 3) ('название', 4) ('оказалось', 4) ('удачным', 3) ('действительно', 4) ('светоносный', 4) ('дал', 1) ('людям', 2) ('и', 1) ('доброе', 3) ('и', 1) ('плохое', 3) ('а', 1) ('окончательные', 6) ('результаты', 4) ('его', 2) ('появления', 5) ('станут', 2) ('ясны', 2) ('лишь', 1) ('через', 2) ('сотни', 2) ('лет', 1) ('или', 2) ('через', 2) ('миллионы', 4) ('уход', 2) ('ночи', 2) ('увеличил', 4) ('для', 1) ('человечества', 5) ('активное', 4) ('время', 2) ('суток', 2) ('особенно', 4) ('в', 0) ('слаборазвитых', 5) ('странах', 2) ('потребность', 3) ('в', 0) ('искусственном', 4) ('освещении', 5) ('значительно', 4) ('сократилась', 4) ('и', 1) ('это', 2) ('привело', 3) ('к', 0) ('колоссальной', 4) ('экономии', 5) ('электроэнергии', 7) ('в', 0) ('небесах', 
# ...

# %% [markdown]
# ### Расторгуева Мария СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

import re
s = re.sub('\n', ' ', s).split(" ")
def vowel(word):
    word= re.sub('[.,-:;?]', '', word)
    if list(word)!=[]:
        num = list(filter(lambda x: x in 'ауеыоэяию', list(word)))
        print ("("+ word+", "+str(len(num))+")")
    
lst = list(map(vowel, s))
# Out:
# (Будучи, 3)
# (в, 0)
# (пятьдесят, 3)
# (раз, 1)
# (ярче, 2)
# (полной, 2)
# (Луны, 2)
# (Люцифер, 3)
# (изменил, 3)
# (картину, 3)
# (земного, 3)
# (неба, 2)
# (изгнал, 2)
# (ночь, 1)
# (Несмотря, 3)
# (на, 1)
# (некоторую, 5)
# (зловещесть, 3)
# (название, 4)
# (оказалось, 4)
# (удачным, 3)
# (действительно, 4)
# ("светоносный", 4)
# (дал, 1)
# (людям, 2)
# (и, 1)
# (доброе, 3)
# (и, 1)
# (плохое, 3)
# (А, 0)
# (окончательные, 6)
# (результаты, 4)
# (его, 2)
# (появления, 5)
# (станут, 2)
# (ясны, 2)
# (лишь, 1)
# (через, 2)
# (сотни, 2)
# (лет, 1)
# (или, 2)
# (через, 2)
# (миллионы, 4)
# (Уход, 1)
# (ночи, 2)
# (увеличил, 4)
# (для, 1)
# (человечества, 5)
# (активное, 4)
# (время, 2)
# (суток, 2)
# (особенно, 4)
# (в, 0)
# (слаборазвитых, 5)
# (странах, 2)
# (Потребность, 3)
# (в, 0)
# (искусственном, 4)
# (освещении, 5)
# (значительно, 4)
# (сократилась, 4)
# (и, 1)
# (это, 2)
# (привело, 3)
# (к, 0)
# (колоссальной, 4)
# (экономии, 5)
# (электроэнергии, 7)
# (В, 0)
# ...

# %% [markdown]
# ### Гвасалия Метью СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
listOfLetters = ['а', 'о', 'и', 'е', 'ё', 'э', 'ы', 'у', 'ю', 'я']
xs = [(word, sum([list(word.lower()).count(letter) for letter in listOfLetters])) for word in s.replace('"','').replace('-','').split()] 
print(*xs,sep = '\n')
# Out:
# ('Будучи', 3)
# ('в', 0)
# ('пятьдесят', 3)
# ('раз', 1)
# ('ярче', 2)
# ('полной', 2)
# ('Луны,', 2)
# ('Люцифер', 3)
# ('изменил', 3)
# ('картину', 3)
# ('земного', 3)
# ('неба,', 2)
# ('изгнал', 2)
# ('ночь.', 1)
# ('Несмотря', 3)
# ('на', 1)
# ('некоторую', 5)
# ('зловещесть,', 3)
# ('название', 4)
# ('оказалось', 4)
# ('удачным:', 3)
# ('действительно,', 4)
# ('светоносный', 4)
# ('дал', 1)
# ('людям', 2)
# ('и', 1)
# ('доброе', 3)
# ('и', 1)
# ('плохое.', 3)
# ('А', 1)
# ('окончательные', 6)
# ('результаты', 4)
# ('его', 2)
# ('появления', 5)
# ('станут', 2)
# ('ясны', 2)
# ('лишь', 1)
# ('через', 2)
# ('сотни', 2)
# ('лет', 1)
# ('или', 2)
# ('через', 2)
# ('миллионы.', 4)
# ('Уход', 2)
# ('ночи', 2)
# ('увеличил', 4)
# ('для', 1)
# ('человечества', 5)
# ('активное', 4)
# ('время', 2)
# ('суток,', 2)
# ('особенно', 4)
# ('в', 0)
# ('слаборазвитых', 5)
# ('странах.', 2)
# ('Потребность', 3)
# ('в', 0)
# ('искусственном', 4)
# ('освещении', 5)
# ('значительно', 4)
# ...

# %% [markdown]
# ### Поддубный Михаил СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
list(
    map(
        lambda word: (
            word, 
            sum(map(lambda letter:word.count(letter),"аеёиоуыэюя"))),
        s.lower().replace('\n',' ').split()
    )
)
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны,', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба,', 2),
#  ('изгнал', 2),
#  ('ночь.', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть,', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным:', 3),
#  ('действительно,', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое.', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('-', 0),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы.', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток,', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
# ...

# %% [markdown]
# ### Миронов Никита СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s=s.lower().strip()
rem =' ,?!;:@.-()/\n`\'  \\'
for i in rem:
    s=s.replace(i, ' ')
s=s.split()
glas=lambda x: x=='а'or x=='о'or x=='и' or x=='е' or x=='ё' or x=='э' or x=='ы' or x=='ю' or x=='я' or x=='у'
result = list(map((lambda y:print((y,len(list(filter(glas,y)))))),s))
# Out:
# ('будучи', 3)
# ('в', 0)
# ('пятьдесят', 3)
# ('раз', 1)
# ('ярче', 2)
# ('полной', 2)
# ('луны', 2)
# ('люцифер', 3)
# ('изменил', 3)
# ('картину', 3)
# ('земного', 3)
# ('неба', 2)
# ('изгнал', 2)
# ('ночь', 1)
# ('несмотря', 3)
# ('на', 1)
# ('некоторую', 5)
# ('зловещесть', 3)
# ('название', 4)
# ('оказалось', 4)
# ('удачным', 3)
# ('действительно', 4)
# ('"светоносный"', 4)
# ('дал', 1)
# ('людям', 2)
# ('и', 1)
# ('доброе', 3)
# ('и', 1)
# ('плохое', 3)
# ('а', 1)
# ('окончательные', 6)
# ('результаты', 4)
# ('его', 2)
# ('появления', 5)
# ('станут', 2)
# ('ясны', 2)
# ('лишь', 1)
# ('через', 2)
# ('сотни', 2)
# ('лет', 1)
# ('или', 2)
# ('через', 2)
# ('миллионы', 4)
# ('уход', 2)
# ('ночи', 2)
# ('увеличил', 4)
# ('для', 1)
# ('человечества', 5)
# ('активное', 4)
# ('время', 2)
# ('суток', 2)
# ('особенно', 4)
# ('в', 0)
# ('слаборазвитых', 5)
# ('странах', 2)
# ('потребность', 3)
# ('в', 0)
# ('искусственном', 4)
# ('освещении', 5)
# ('значительно', 4)
# ('сократилась', 4)
# ...

# %% [markdown]
# ### Шубин Никита СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

mys = s.lower()
mys = (reduce(lambda mys, r:s.replace(r, ''), '—,.«»!?', mys))
lst = list(mys.split())

print(tuple(zip(lst, list(map(lambda x: lst[x].count("а") + lst[x].count("е") + lst[x].count("ё") + lst[x].count("и") + lst[x].count("о") + lst[x].count("у") + lst[x].count("ы") + lst[x].count("э") + lst[x].count("ю") + lst[x].count("я"), range(len(lst)))) )))
# Out:
# (('Будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('Луны,', 2), ('Люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба,', 2), ('изгнал', 2), ('ночь.', 1), ('Несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть,', 3), ('название', 4), ('оказалось', 4), ('удачным:', 3), ('действительно,', 4), ('"светоносный"', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое.', 3), ('А', 0), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('-', 0), ('или', 2), ('через', 2), ('миллионы.', 4), ('Уход', 1), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток,', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах.', 2), ('Потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась,', 4), ('и', 1), ('это', 2), ('привело', 3), 
# ...

# %% [markdown]
# ### Щеглова Полина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from functools import reduce
t = reduce(lambda s, r:s.replace(r, ' '), '\t\n\.,\?!\-:"', s)
t = t.split()
filter('', t) # t состоит только из слов строки
rus_vowels= [0,'у','е','а','ы','о','э','я','и','ю','ё','У','Е','Ы','А','О','Э','Я','И','Ю','Ё']

func = lambda word: reduce(lambda c,s: c+word.count(s), rus_vowels)
    
lst = list(zip(t, list(map(func, t)))) # для каждого слова считаем количество всех гласных с помощью map

print(lst)
# Out:
# [('Будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('Луны', 2), ('Люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('Несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('А', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('Уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('Потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Мухамадиева Регина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''
import functools
for i in "!?/\'\":;(),.-`\n\t":
    s=s.replace(i,' ')
s=s.lower().split()
l=set("уеыаоэёяию")
print(list(map(lambda el:(el,list(map(lambda i: i in l,el)).count(True)),s)))
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Астраханцев Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
import re
from functools import reduce
lst = re.sub(r'[\.\?\-\,\"\:\n\;]', '', s.lower()).split()
alphabet = "аяуюэеиыоё"
list(zip(lst, map(lambda wrd: reduce(lambda a,lett: a+1 if lett in alphabet else a, wrd, 0), lst)))
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картинуземного', 6),
#  ('неба', 2),
#  ('изгнал', 2),
#  ('ночь', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть', 3),
#  ('названиеоказалось', 8),
#  ('удачным', 3),
#  ('действительно', 4),
#  ('светоносный', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('иплохое', 4),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('черезсотни', 4),
#  ('лет', 1),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток', 2),
#  ('особеннов', 4),
#  ('слаборазвитых', 5),
#  ('странах', 2),
#  ('потребность', 3),
#  ('в', 0),
#  ('искусственном', 4),
# ...

# %% [markdown]
# ### Бесчастных Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
def formater(s):
    string = s.lower().strip()
    chars = ['\\', '\n', '  ', '?', '.', ',', '-', ':', ';', '\"']
    for c in chars:
        string = string.replace(c, ' ')
    arr = string.split(' ')
    arr = list(filter(lambda x: len(x) > 0, arr))
    return arr


def getStatForEachWord(array):
    dict = ()
    counter = 0
    vowels = ['а', 'у', 'е', 'ы', 'о', 'э', 'я', 'и', 'ю']
    for item in array:
        for symbol in vowels:
            counter += item.count(symbol)
        print((item, counter))
        counter = 0

# %%
getStatForEachWord(formater(s))
# Out:
# ('будучи', 3)
# ('в', 0)
# ('пятьдесят', 3)
# ('раз', 1)
# ('ярче', 2)
# ('полной', 2)
# ('луны', 2)
# ('люцифер', 3)
# ('изменил', 3)
# ('картину', 3)
# ('земного', 3)
# ('неба', 2)
# ('изгнал', 2)
# ('ночь', 1)
# ('несмотря', 3)
# ('на', 1)
# ('некоторую', 5)
# ('зловещесть', 3)
# ('название', 4)
# ('оказалось', 4)
# ('удачным', 3)
# ('действительно', 4)
# ('светоносный', 4)
# ('дал', 1)
# ('людям', 2)
# ('и', 1)
# ('доброе', 3)
# ('и', 1)
# ('плохое', 3)
# ('а', 1)
# ('окончательные', 6)
# ('результаты', 4)
# ('его', 2)
# ('появления', 5)
# ('станут', 2)
# ('ясны', 2)
# ('лишь', 1)
# ('через', 2)
# ('сотни', 2)
# ('лет', 1)
# ('или', 2)
# ('через', 2)
# ('миллионы', 4)
# ('уход', 2)
# ('ночи', 2)
# ('увеличил', 4)
# ('для', 1)
# ('человечества', 5)
# ('активное', 4)
# ('время', 2)
# ('суток', 2)
# ('особенно', 4)
# ('в', 0)
# ('слаборазвитых', 5)
# ('странах', 2)
# ('потребность', 3)
# ('в', 0)
# ('искусственном', 4)
# ('освещении', 5)
# ('значительно', 4)
# ('сократилась', 4)
# ...

# %% [markdown]
# ### Музаффаров Руфат СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
### строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

glasnie = ['а','е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']

import re
s = re.sub(r'[^\w\s]','',s)
low_s = s.lower().split()

d = dict()
lst = list(map(lambda x: 
             sum(list(map(lambda y: y in glasnie, x))), low_s))
d = list(zip(low_s,lst))
print(d)
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Гаварина Светлана СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
import re

def count_vow(s):
    return map(lambda x: (x, len(re.findall('[ёуеыаоэяию]', x.lower()))),
                filter(None,
                    re.sub('[!?.:;,\"\n]', ' ', s).replace(' - ', ' ').split()
                    )
                )
                 

print(*count_vow(s))
# Out:
# ('Будучи', 3) ('в', 0) ('пятьдесят', 3) ('раз', 1) ('ярче', 2) ('полной', 2) ('Луны', 2) ('Люцифер', 3) ('изменил', 3) ('картину', 3) ('земного', 3) ('неба', 2) ('изгнал', 2) ('ночь', 1) ('Несмотря', 3) ('на', 1) ('некоторую', 5) ('зловещесть', 3) ('название', 4) ('оказалось', 4) ('удачным', 3) ('действительно', 4) ('светоносный', 4) ('дал', 1) ('людям', 2) ('и', 1) ('доброе', 3) ('и', 1) ('плохое', 3) ('А', 1) ('окончательные', 6) ('результаты', 4) ('его', 2) ('появления', 5) ('станут', 2) ('ясны', 2) ('лишь', 1) ('через', 2) ('сотни', 2) ('лет', 1) ('или', 2) ('через', 2) ('миллионы', 4) ('Уход', 2) ('ночи', 2) ('увеличил', 4) ('для', 1) ('человечества', 5) ('активное', 4) ('время', 2) ('суток', 2) ('особенно', 4) ('в', 0) ('слаборазвитых', 5) ('странах', 2) ('Потребность', 3) ('в', 0) ('искусственном', 4) ('освещении', 5) ('значительно', 4) ('сократилась', 4) ('и', 1) ('это', 2) ('привело', 3) ('к', 0) ('колоссальной', 4) ('экономии', 5) ('электроэнергии', 7) ('В', 0) ('небесах', 
# ...

# %% [markdown]
# ### Дундуков Семен СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %% [markdown]
# ### Бень Таисия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
def number(word):
    if len(word)>0:
        pass
    vowel = 'аяуюоёэеыи'
    if len(word)>0:
        vow = list(filter(lambda x: x in vowel, word))
        return word,len(vow)
text = s.lower()
text = text.replace('\n',' ')
for let in ".,-:;?":
    text = text.replace(let,'')
text = text.split()
list(map(number, text))
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба', 2),
#  ('изгнал', 2),
#  ('ночь', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным', 3),
#  ('действительно', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
#  ('странах', 2),
# ...

# %% [markdown]
# ### Козликина Татьяна СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
dictionary = {}
letter = ['а', 'е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']

#Приводим текст к нижнему регистру и убираем лишние символы

sym = ['?', '.', ',', ':', ';', '"', '-']
s = s.lower()
for i in range(len(sym)):
    s = s.replace(sym[i], ' ')
s = s.split()

#Проходимся по тексту строки

for w in s: 
    k=0
    if w not in dictionary:
        dictionary[w] = 0
    for n in range(len(letter)):
        k+=w.count(letter[n])
    dictionary[w]+= k
    

#Вывод в требуемом формате

for key, value in dictionary.items():
    print('(%s, %d)'%(key, value))
# Out:
# (будучи, 3)
# (в, 0)
# (пятьдесят, 3)
# (раз, 1)
# (ярче, 2)
# (полной, 2)
# (луны, 2)
# (люцифер, 9)
# (изменил, 3)
# (картину, 3)
# (земного, 3)
# (неба, 4)
# (изгнал, 2)
# (ночь, 1)
# (несмотря, 3)
# (на, 7)
# (некоторую, 5)
# (зловещесть, 3)
# (название, 4)
# (оказалось, 4)
# (удачным, 3)
# (действительно, 4)
# (светоносный, 4)
# (дал, 1)
# (людям, 2)
# (и, 14)
# (доброе, 3)
# (плохое, 3)
# (а, 2)
# (окончательные, 6)
# (результаты, 4)
# (его, 4)
# (появления, 5)
# (станут, 2)
# (ясны, 2)
# (лишь, 2)
# (через, 4)
# (сотни, 2)
# (лет, 1)
# (или, 2)
# (миллионы, 4)
# (уход, 2)
# (ночи, 4)
# (увеличил, 4)
# (для, 1)
# (человечества, 5)
# (активное, 4)
# (время, 2)
# (суток, 2)
# (особенно, 4)
# (слаборазвитых, 5)
# (странах, 2)
# (потребность, 3)
# (искусственном, 4)
# (освещении, 5)
# (значительно, 4)
# (сократилась, 4)
# (это, 2)
# (привело, 3)
# (к, 0)
# (колоссальной, 4)
# (экономии, 5)
# (электроэнергии, 7)
# (небесах, 3)
# (зажглась, 2)
# (мощнейшая, 4)
# (лампа, 2)
# ...

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

letters = ['а', 'е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']
sym = ['?', '.', ',', ':', ';', '"', '-']
s = s.lower()
for i in range(len(sym)):
    s = s.replace(sym[i], ' ')
s = s.split()

list_s = list(map(lambda x: sum(x.count(l) for l in letters), s))
z = list(zip(s, list_s))
print(z)
# Out:
# [('будучи', 3), ('в', 0), ('пятьдесят', 3), ('раз', 1), ('ярче', 2), ('полной', 2), ('луны', 2), ('люцифер', 3), ('изменил', 3), ('картину', 3), ('земного', 3), ('неба', 2), ('изгнал', 2), ('ночь', 1), ('несмотря', 3), ('на', 1), ('некоторую', 5), ('зловещесть', 3), ('название', 4), ('оказалось', 4), ('удачным', 3), ('действительно', 4), ('светоносный', 4), ('дал', 1), ('людям', 2), ('и', 1), ('доброе', 3), ('и', 1), ('плохое', 3), ('а', 1), ('окончательные', 6), ('результаты', 4), ('его', 2), ('появления', 5), ('станут', 2), ('ясны', 2), ('лишь', 1), ('через', 2), ('сотни', 2), ('лет', 1), ('или', 2), ('через', 2), ('миллионы', 4), ('уход', 2), ('ночи', 2), ('увеличил', 4), ('для', 1), ('человечества', 5), ('активное', 4), ('время', 2), ('суток', 2), ('особенно', 4), ('в', 0), ('слаборазвитых', 5), ('странах', 2), ('потребность', 3), ('в', 0), ('искусственном', 4), ('освещении', 5), ('значительно', 4), ('сократилась', 4), ('и', 1), ('это', 2), ('привело', 3), ('к', 0), ('колоссально
# ...

# %% [markdown]
# ### Апресян Тигран СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
from pprint import pprint
from functools import reduce
our_updated = reduce(lambda s, r:s.replace(r, ''), '—,.«»`!---\?:--:;)(*', s).lower().split()
s1 = ['а','е','и','о','у','ы','э','ю','я','ё']
pprint(list(zip(our_updated,list(map(lambda b:sum(list(map(lambda a: a in s1,b))),our_updated)))))
# Out:
# [('будучи', 3),
#  ('в', 0),
#  ('пятьдесят', 3),
#  ('раз', 1),
#  ('ярче', 2),
#  ('полной', 2),
#  ('луны', 2),
#  ('люцифер', 3),
#  ('изменил', 3),
#  ('картину', 3),
#  ('земного', 3),
#  ('неба', 2),
#  ('изгнал', 2),
#  ('ночь', 1),
#  ('несмотря', 3),
#  ('на', 1),
#  ('некоторую', 5),
#  ('зловещесть', 3),
#  ('название', 4),
#  ('оказалось', 4),
#  ('удачным', 3),
#  ('действительно', 4),
#  ('"светоносный"', 4),
#  ('дал', 1),
#  ('людям', 2),
#  ('и', 1),
#  ('доброе', 3),
#  ('и', 1),
#  ('плохое', 3),
#  ('а', 1),
#  ('окончательные', 6),
#  ('результаты', 4),
#  ('его', 2),
#  ('появления', 5),
#  ('станут', 2),
#  ('ясны', 2),
#  ('лишь', 1),
#  ('через', 2),
#  ('сотни', 2),
#  ('лет', 1),
#  ('или', 2),
#  ('через', 2),
#  ('миллионы', 4),
#  ('уход', 2),
#  ('ночи', 2),
#  ('увеличил', 4),
#  ('для', 1),
#  ('человечества', 5),
#  ('активное', 4),
#  ('время', 2),
#  ('суток', 2),
#  ('особенно', 4),
#  ('в', 0),
#  ('слаборазвитых', 5),
#  ('странах', 2),
# ...

# %% [markdown]
# ### Долотов Фёдор СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

import re
s = s.lower()
s = s.split()
i = 0

def wovels_quantity (string):
    quantity = len(re.findall('[уеыаоэяиюё]', string, re.IGNORECASE))
    return(str(quantity))

l = list(map(lambda i: '(' + s[i] + ', ' + wovels_quantity(s[i]) + ')', range(len(s))))
print(l)
# Out:
# ['(будучи, 3)', '(в, 0)', '(пятьдесят, 3)', '(раз, 1)', '(ярче, 2)', '(полной, 2)', '(луны,, 2)', '(люцифер, 3)', '(изменил, 3)', '(картину, 3)', '(земного, 3)', '(неба,, 2)', '(изгнал, 2)', '(ночь., 1)', '(несмотря, 3)', '(на, 1)', '(некоторую, 5)', '(зловещесть,, 3)', '(название, 4)', '(оказалось, 4)', '(удачным:, 3)', '(действительно,, 4)', '("светоносный", 4)', '(дал, 1)', '(людям, 2)', '(и, 1)', '(доброе, 3)', '(и, 1)', '(плохое., 3)', '(а, 1)', '(окончательные, 6)', '(результаты, 4)', '(его, 2)', '(появления, 5)', '(станут, 2)', '(ясны, 2)', '(лишь, 1)', '(через, 2)', '(сотни, 2)', '(лет, 1)', '(-, 0)', '(или, 2)', '(через, 2)', '(миллионы., 4)', '(уход, 2)', '(ночи, 2)', '(увеличил, 4)', '(для, 1)', '(человечества, 5)', '(активное, 4)', '(время, 2)', '(суток,, 2)', '(особенно, 4)', '(в, 0)', '(слаборазвитых, 5)', '(странах., 2)', '(потребность, 3)', '(в, 0)', '(искусственном, 4)', '(освещении, 5)', '(значительно, 4)', '(сократилась,, 4)', '(и, 1)', '(это, 2)', '(привело, 3)', 
# ...

# %% [markdown]
# ### Попов Юрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# строка s содержит текст
# используя только функциональные возможности Python (map, reduce, zip, и др.)
# для каждого слова подсчитать количество гласных букв, содержащихся в нем
# вывести на экран все пары:
# (слово, количество_гласных_букв_в_нем)

s = '''
Будучи в  пятьдесят раз  ярче полной Луны,  Люцифер изменил картину
земного неба,  изгнал ночь.  Несмотря на некоторую зловещесть,  название
оказалось удачным:  действительно,  "светоносный" дал  людям и  доброе и
плохое.  А окончательные результаты его появления станут ясны лишь через
сотни лет - или через миллионы.
     Уход ночи увеличил для человечества активное время суток,  особенно
в   слаборазвитых  странах.   Потребность   в   искусственном  освещении
значительно  сократилась,   и   это  привело  к   колоссальной  экономии
электроэнергии.  В небесах зажглась мощнейшая лампа,  озаряющая полмира.
Да и днем Люцифер соперничал с Солнцем:  предметы отбрасывали отчетливые
двойные тени.
     Фермеры, моряки, полицейские - все, кто работал под открытым небом,
- приветствовали его появление:
     Люцифер облегчил их  жизнь  и  сделал  ее  более  безопасной.  Зато
обижены оказались влюбленные, преступники, натуралисты и астрономы.
     Влюбленным и  преступникам приходилось теперь нелегко,  натуралисты
же беспокоились за флору и фауну.  Пострадали многие ночные животные,  а
рыбам одного тихоокеанского вида,  которые размножались лишь при высоком
приливе и в безлунные ночи, грозило полное вымирание.
     Как и астрономам,  работавшим на Земле. Впрочем, поскольку половина
всех астрономических инструментов и без того располагалась в космическом
пространстве и на Луне,  катастрофой последнее не грозило. Свет Люцифера
мешал только земным обсерваториям.
     Человечество приспособится,  как неоднократно случалось в  прошлом.
Скоро на смену придут поколения,  не знающие другого неба;  но людей еще
долго будет мучить тайна происхождения Люцифера.
     Почему был принесен в жертву Юпитер? На сколько веков хватит нового
солнца?  И  главное -  почему наложен запрет на Европу,  закрытую теперь
облаками, подобно Венере?
     Ответы  на  все  эти  вопросы,  конечно,  есть.  И  человечество не
успокоится, пока не найдет их.'''

# %%
# Задание_12

letters = ['а', 'е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']
sym = ['?', '.', ',', ':', ';', '"', '-']
s = s.lower()

#ретушируем текст
for i in range(len(sym)):
    s = s.replace(sym[i], ' ')
s = s.split()

list_s = list(map(lambda x: sum(x.count(l) for l in letters), s))
z = list(zip(s, list_s))
for i in z:
    print(i)
# Out:
# ('будучи', 3)
# ('в', 0)
# ('пятьдесят', 3)
# ('раз', 1)
# ('ярче', 2)
# ('полной', 2)
# ('луны', 2)
# ('люцифер', 3)
# ('изменил', 3)
# ('картину', 3)
# ('земного', 3)
# ('неба', 2)
# ('изгнал', 2)
# ('ночь', 1)
# ('несмотря', 3)
# ('на', 1)
# ('некоторую', 5)
# ('зловещесть', 3)
# ('название', 4)
# ('оказалось', 4)
# ('удачным', 3)
# ('действительно', 4)
# ('светоносный', 4)
# ('дал', 1)
# ('людям', 2)
# ('и', 1)
# ('доброе', 3)
# ('и', 1)
# ('плохое', 3)
# ('а', 1)
# ('окончательные', 6)
# ('результаты', 4)
# ('его', 2)
# ('появления', 5)
# ('станут', 2)
# ('ясны', 2)
# ('лишь', 1)
# ('через', 2)
# ('сотни', 2)
# ('лет', 1)
# ('или', 2)
# ('через', 2)
# ('миллионы', 4)
# ('уход', 2)
# ('ночи', 2)
# ('увеличил', 4)
# ('для', 1)
# ('человечества', 5)
# ('активное', 4)
# ('время', 2)
# ('суток', 2)
# ('особенно', 4)
# ('в', 0)
# ('слаборазвитых', 5)
# ('странах', 2)
# ('потребность', 3)
# ('в', 0)
# ('искусственном', 4)
# ('освещении', 5)
# ('значительно', 4)
# ('сократилась', 4)
# ...
