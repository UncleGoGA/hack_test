# %% [markdown]
# -----
# #### Задание 9

# %% [markdown]
# ### Федоров Сергей СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# ЗАДАНИЕ 1

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

sorted(lst, key=lambda lstt: (lstt[1][1])/(lstt[1][0]), reverse=True) # №1
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
# ЗАДАНИЕ 2 

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
r = sorted(lst, key=lambda lstt: lstt[1][1], reverse=1)
# print(r)
t = 0
k = []
for i in range(0,len(r)):
 if i == len(r)-1:
   if r[i][1][1] == r[len(r)-1][1][1]:
       k = k + sorted(r[t:i+1], key=lambda lstt: lstt[0])
       break
   else:
    k.append(r[i])
    k.append((r[len(r)-1]))
    break
 else:
    if r[i][1][1] == r[i+1][1][1]:
        # print(' len = ', len(r), ' t ===== ', t)
        # print(' len = ', len(r), ' i ===== ', i)
        # print(' lenПППППП = ', len(k))
        continue
    else:
        k = k + sorted(r[t:i+1], key=lambda lstt: lstt[0])
        t = i+1


# # print(' r[len(r)][1][0]   ===========', r[len(r)][1][0])

# print('len k === ', len(k), "len (r ) = ",len(r))
# print(r)
print(*k, sep='\n')
# Out:
# ('е', (2, 197))
# ('з', (32, 195))
# ('е', (7, 184))
# ('ю', (4, 179))
# ('г', (7, 174))
# ('ф', (2, 161))
# ('р', (1, 159))
# ('к', (1, 157))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('и', (3, 136))
# ('т', (8, 135))
# ('п', (9, 133))
# ('я', (6, 131))
# ('ж', (9, 129))
# ('м', (6, 129))
# ('х', (1, 129))
# ('з', (1, 125))
# ('х', (4, 125))
# ('э', (15, 93))

# %% [markdown]
# ### Алексеев Кирилл СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]


def Sort1(list):
    i = 0
    characterList = []
    numList = []
    while i < len(list):
        characterList.append(list[i][1][1] / list[i][1][0])
        numList.append(i)
        i = i + 1    
         
    k = len(characterList)
    while k > 0:
        i = 0
        while i < k - 1:
            if characterList[i] < characterList[i + 1]:
                c = characterList[i]
                characterList[i] = characterList[i + 1]
                characterList[i + 1] = c
                c = numList[i]
                numList[i] = numList[i + 1]
                numList[i + 1] = c
            i = i + 1
        k = k - 1
    i = 0
    characterList = []
    while i < len(numList):
        characterList.append(list[numList[i]])
        i = i + 1
    return characterList

def Sort2(list):
    i = 0
    characterList = []
    numList = []
    letterList = []
    while i < len(list):
        characterList.append(list[i][1][1])
        letterList.append(list[i][0])
        numList.append(i)
        i = i + 1
    k = len(characterList)
    while k > 0:
        i = 0
        while i < k - 1:
            if (characterList[i] < characterList[i + 1]) or ((characterList[i] == characterList[i + 1]) and (letterList[i] > letterList[i + 1])):
                c = characterList[i]
                characterList[i] = characterList[i + 1]
                characterList[i + 1] = c
                c = numList[i]
                numList[i] = numList[i + 1]
                numList[i + 1] = c
                p = letterList[i]
                letterList[i] = letterList[i + 1]
                letterList[i + 1] = p
            i = i + 1
        k = k - 1
    characterList = []
    while i < len(numList):
        characterList.append(list[numList[i]])
        i = i + 1
    return characterList
  
print(Sort1(lst))
print(Sort2(lst))
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Анчугов Роман СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
new1 = sorted(lst, key = lambda value: value[1][1] / value[1][0], reverse = True)
new2 = sorted(lst, key = lambda value: value[1][1], reverse = True)
i = 0
while i < len(new2):
    start = i
    end = i
    while end < len(new2) and new2[start][1][1] == new2[end][1][1]:
        i += 1
        end = i
    new2[start:end] = sorted(new2[start:end], key=lambda value: value[0])  
(new1, new2)
# Out:
# ([('р', (1, 159)),
#   ('к', (1, 157)),
#   ('ж', (1, 136)),
#   ('х', (1, 129)),
#   ('з', (1, 125)),
#   ('е', (2, 197)),
#   ('ф', (2, 161)),
#   ('б', (2, 156)),
#   ('и', (3, 136)),
#   ('ю', (4, 179)),
#   ('х', (4, 125)),
#   ('е', (7, 184)),
#   ('г', (7, 174)),
#   ('я', (6, 131)),
#   ('м', (6, 129)),
#   ('т', (8, 135)),
#   ('п', (9, 133)),
#   ('ж', (9, 129)),
#   ('э', (15, 93)),
#   ('з', (32, 195))],
#  [('е', (2, 197)),
#   ('з', (32, 195)),
#   ('е', (7, 184)),
#   ('ю', (4, 179)),
#   ('г', (7, 174)),
#   ('ф', (2, 161)),
#   ('р', (1, 159)),
#   ('к', (1, 157)),
#   ('б', (2, 156)),
#   ('ж', (1, 136)),
#   ('и', (3, 136)),
#   ('т', (8, 135)),
#   ('п', (9, 133)),
#   ('я', (6, 131)),
#   ('ж', (9, 129)),
#   ('м', (6, 129)),
#   ('х', (1, 129)),
#   ('з', (1, 125)),
#   ('х', (4, 125)),
#   ('э', (15, 93))])

# %% [markdown]
# ### Акинина Алёна СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = [('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
print(sorted(lst,key = lambda x : x[1][1]/x[1][0],reverse = True))
print(sorted(sorted(lst,key = lambda x : x[0]),key = lambda x : x[1][1],reverse = True))
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Лисьев Александр СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
sorted(lst, key = lambda x: x[1][1] / x[1][0], reverse=True)
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2
sorted(sorted(lst, key = lambda x: x[0]), key = lambda x: x[1][1], reverse=True)
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Чердак Александр СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#PART #1

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst = sorted(lst, key = lambda item: item[1][1] / item[1][0], reverse = True)
print(lst)

print('#########')

#PART #2

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst = sorted(lst, key = lambda item: (-item[1][1], item[0]))
print(lst)
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# #########
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Шелепова Алена СКБ172
#
# Оценка: 0.5
#
# Комментарий: First re

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# 1. по отношению второго числа из кортежа к первому по убыванию
sorted(lst, key=lambda i: (i[1][1]//i[1][0]), reverse = True)
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('м', (6, 129)),
#  ('я', (6, 131)),
#  ('т', (8, 135)),
#  ('ж', (9, 129)),
#  ('п', (9, 133)),
#  ('з', (32, 195)),
#  ('э', (15, 93))]

# %%
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию
sorted(lst, key=lambda i: (-i[1][1], i[0]))
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Шнейдер Алиса СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# Пункт 1
lst.sort(key=lambda x: -x[1][1] / x[1][0])
lst
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2
lst.sort(key=lambda x: -x[1][1])
lst
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('х', (1, 129)),
#  ('м', (6, 129)),
#  ('ж', (9, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Зайцева Анастасия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst.sort(key = lambda i: i[1][1] / i[1][0] , reverse = True)
lst
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst.sort(key = lambda i: i[0])
lst.sort(key = lambda i: i[1][1], reverse = True)
lst
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Полуяктов Анатолий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst=sorted(lst,key=lambda x:x[1][1]/x[1][0],reverse=True)
lst
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
lst=sorted(lst,key=lambda x:(-x[1][1],x[0]))
lst
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Фомин Андрей СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst.sort(key=lambda x: x[1][1] / x[1][0], reverse=True)
print(lst)
print()
lst.sort(key = lambda x:x[0],reverse=True)
lst.sort(key = lambda x: x[1][1],reverse=True)
print(lst)
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
#
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('и', (3, 136)), ('ж', (1, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('х', (1, 129)), ('м', (6, 129)), ('ж', (9, 129)), ('х', (4, 125)), ('з', (1, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Марипова Жасмин СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst1 = sorted(lst, key = lambda x: x[1][1] / x[1][0], reverse = True) # 1 задание
lst1
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst2 = sorted(lst, key = lambda x: (-x[1][1], x[0])) # 2 задание
lst2
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Зоричев Борис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
lst.sort(key=lambda i: i[1][1] / i[1][0], reverse = True)
print(lst)
lst.sort(key=lambda i: (-i[1][1], ord(i[0])))
print(lst)
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Сербаев Вадим СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst1 = lst

#1
def ListSort1(lst):
        return lst[1][1]/lst[1][0]
lst.sort(key=ListSort1, reverse = True)
print(lst)

#2
def ListSort2(lst1):
        return lst1[1][1]
lst1.sort(key=ListSort2, reverse = True)

def ListSortAlphabet(lst2):
        return lst2[0]
    
def AfterListSort(lst1):
    finallist=[]
    lst2=[]
    i=0
    while i<len(lst1):
        ireg = i
        reg = lst1[i][1][1]
        while ireg<len(lst1):
            if(lst1[ireg][1][1]==reg):
                lst2.append(lst1[ireg])
                i = ireg
            ireg+=1
        lst2.sort(key=ListSortAlphabet)
        #print(lst2)
        finallist.extend(lst2)
        lst2=[]
        #print(i)
        i+=1
    print(finallist)
        
AfterListSort(lst1)
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Булгаков Виталий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
a1 = sorted(lst, key = lambda x : x[1][1] / x[1][0], reverse = True)
a2 = sorted(sorted(lst, key = lambda x: x[0]), key = lambda x: x[1][1], reverse = True)
print(a1, a2) #для удобочитаемой версии вывода, лучше выводить по отдельности a1 и a2
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))] [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Андреева Влада СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
a = sorted(lst, key=lambda i: i[1][1] / i[1][0], reverse=True)
print('Лист, отсортированный по условию в #1:\n', a, '\n')

#2
a = sorted(lst, key=lambda i: i[1][1], reverse=True)
final = []
i = 0
while i < len(a):
    l = [a[i]]
    if i == 0:
        if a[0][1][1] == a[1][1][1]:
            l.append(a[1])
            i += 1
    i += 1
    if i < len(a):
        while a[i][1][1] == a[i-1][1][1] and 0 < i < len(a):
            l.append(a[i])
            i += 1
        l = sorted(l, key=lambda i: i[0])
    final.extend(l)
print('Лист, отсортированный по условию в #2\n', final)
# Out:
# Лист, отсортированный по условию в #1:
#  [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
#
# Лист, отсортированный по условию в #2
#  [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Клопов Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst.sort(key=lambda x: x[1][1]/x[1][0],reverse=True)
lst
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst.sort(key=lambda x: (ord(x[0])/1000)-x[1][1])
lst
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Сарахан Владислав СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
def first(a):
    return -(a[1][1] / a[1][0])

# %%
sorted(lst, key=first)
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
def second(a):
    return -(a[1][1] - ord(a[0]) / 100)

# %%
sorted(lst, key=second)
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Старостин Данила СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
lst2 = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

def func(lst):
    return -lst[1][1] / lst[1][0]

def func2(lst2):
    return -lst2[1][1], lst[0] 

lst.sort(key=func)
lst2.sort(key=func2)
print(*lst)
print(*lst2)
# Out:
# ('р', (1, 159)) ('к', (1, 157)) ('ж', (1, 136)) ('х', (1, 129)) ('з', (1, 125)) ('е', (2, 197)) ('ф', (2, 161)) ('б', (2, 156)) ('и', (3, 136)) ('ю', (4, 179)) ('х', (4, 125)) ('е', (7, 184)) ('г', (7, 174)) ('я', (6, 131)) ('м', (6, 129)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))
# ('е', (2, 197)) ('з', (32, 195)) ('е', (7, 184)) ('ю', (4, 179)) ('г', (7, 174)) ('ф', (2, 161)) ('р', (1, 159)) ('к', (1, 157)) ('б', (2, 156)) ('ж', (1, 136)) ('и', (3, 136)) ('т', (8, 135)) ('п', (9, 133)) ('я', (6, 131)) ('ж', (9, 129)) ('м', (6, 129)) ('х', (1, 129)) ('з', (1, 125)) ('х', (4, 125)) ('э', (15, 93))

# %% [markdown]
# ### Стрекнев Денис СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
l1=sorted(lst, key=lambda x: x[1][1]/x[1][0], reverse=True)
l1
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2
l1=sorted(lst, key=lambda x: x[0])
l1=sorted(l1, key=lambda x: x[1][1], reverse=True)
l1
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Дородный Дмитрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(*sorted(lst, key = lambda x: x[1][1]/x[1][0], reverse = True), '', *sorted(sorted(lst, key = lambda x: x[0]), key = lambda x: x[1][1], reverse = True), sep = '\n')
# Out:
# ('р', (1, 159))
# ('к', (1, 157))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('е', (2, 197))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('е', (7, 184))
# ('г', (7, 174))
# ('я', (6, 131))
# ('м', (6, 129))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
# ('е', (2, 197))
# ('з', (32, 195))
# ('е', (7, 184))
# ('ю', (4, 179))
# ('г', (7, 174))
# ('ф', (2, 161))
# ('р', (1, 159))
# ('к', (1, 157))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('и', (3, 136))
# ('т', (8, 135))
# ('п', (9, 133))
# ('я', (6, 131))
# ('ж', (9, 129))
# ('м', (6, 129))
# ('х', (1, 129))
# ('з', (1, 125))
# ('х', (4, 125))
# ('э', (15, 93))

# %% [markdown]
# ### Шемякин Дмитрий СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

#1
lst = sorted(lst, key = lambda x: x[1][1] / x[1][0], reverse = True)

lst
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

#2
lst = sorted(lst, key = lambda x: (-x[1][1], x[0]))

lst
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Никитина Елизавета СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

rlst = { a[1][1]/a[1][0]: a[0] for a in lst}
result = [ rlst[a] for a in sorted(rlst.keys(), reverse=True) ]
print(result)
print('---')
arr = [(a[0], a[1][0]) for a in lst]
arr2sort = {}
for a in arr:
    if a[1] not in arr2sort:
        arr2sort[a[1]] = []
    arr2sort[a[1]].append(a[0])
result = []
for a in sorted(arr2sort.keys(), reverse=True):
    arr2sort[a].sort()
    result += arr2sort[a]
print(result)
# Out:
# ['р', 'к', 'ж', 'х', 'з', 'е', 'ф', 'б', 'и', 'ю', 'х', 'е', 'г', 'я', 'м', 'т', 'п', 'ж', 'э', 'з']
# ---
# ['з', 'э', 'ж', 'п', 'т', 'г', 'е', 'м', 'я', 'х', 'ю', 'и', 'б', 'е', 'ф', 'ж', 'з', 'к', 'р', 'х']

# %% [markdown]
# ### Семенов Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print('#1 ',sorted(lst, key=lambda t:t[1][1]/t[1][0],reverse=True))
print("---------------------------------------")
print('#2 ',sorted(lst, key=lambda t:t[1][1]*1000000-ord(t[0]),reverse=True))
# Out:
# #1  [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# ---------------------------------------
# #2  [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Шамрин Игорь СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
sorted(lst, key = lambda x: x[1][1]/x[1][0], reverse = True)

sorted(sorted(lst, key = lambda x: x[0]), key = lambda x: x[1][1], reverse = True)
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Щербаков Игорь СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
def doublesort(x, primary, secondary, primary_reverse=False, secondary_reverse=False): #Используем повторно
    s=sorted(x, key=secondary, reverse=secondary_reverse)
    s=sorted(s, key=primary, reverse=primary_reverse)
    return s

s1 = sorted(lst, key=lambda t: 1.0*t[1][1]/(t[1][0]), reverse=True) # 1. по отношению второго числа из кортежа к первому по убыванию
for item in s1:
    print(item)
print('\n')

s2= doublesort(lst,primary= lambda t: t[1][1], secondary =lambda t: t[0],primary_reverse=True)# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию
for item in s2:
    print(item)
# Out:
# ('р', (1, 159))
# ('к', (1, 157))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('е', (2, 197))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('е', (7, 184))
# ('г', (7, 174))
# ('я', (6, 131))
# ('м', (6, 129))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
#
# ('е', (2, 197))
# ('з', (32, 195))
# ('е', (7, 184))
# ('ю', (4, 179))
# ('г', (7, 174))
# ('ф', (2, 161))
# ('р', (1, 159))
# ('к', (1, 157))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('и', (3, 136))
# ('т', (8, 135))
# ('п', (9, 133))
# ('я', (6, 131))
# ('ж', (9, 129))
# ('м', (6, 129))
# ('х', (1, 129))
# ('з', (1, 125))
# ('х', (4, 125))
# ('э', (15, 93))

# %% [markdown]
# ### Шомахов Идар СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst = sorted(lst, key = lambda x: x[1][1] / x[1][0], reverse = True) # 1 задание
lst
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst = sorted(lst, key = lambda x: (-x[1][1], x[0])) # 2 задание
lst
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Григорьев Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

print(sorted(lst, key = lambda n: (n[1][1]/n[1][0]), reverse = True))#1
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

print(sorted(sorted(lst, key = lambda n: n[0]), key = lambda n:n[1][1], reverse = True))#2
# Out:
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Фомин Илья СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
sorted(lst,key=lambda x: -x[1][1]/x[1][0])
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2 
sorted(lst,key=lambda x:(-x[1][1],x[0]))
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Синицын Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
print(sorted(lst, key = lambda x: x[1][1] / x[1][0], reverse = True))
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %%
#2
print(sorted(sorted(lst, key = lambda x: x[0]), key = lambda x: x[1][1], reverse = True))
# Out:
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Смирнов Константин СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(*sorted(lst, key=lambda i: i[1][1] / i[1][0], reverse=True))
# Out:
# ('р', (1, 159)) ('к', (1, 157)) ('ж', (1, 136)) ('х', (1, 129)) ('з', (1, 125)) ('е', (2, 197)) ('ф', (2, 161)) ('б', (2, 156)) ('и', (3, 136)) ('ю', (4, 179)) ('х', (4, 125)) ('е', (7, 184)) ('г', (7, 174)) ('я', (6, 131)) ('м', (6, 129)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))

# %%
from fn import _
print(*sorted(sorted(lst, key=_[0]), key=_[1][1], reverse=True))
# Out:
# ('е', (2, 197)) ('з', (32, 195)) ('е', (7, 184)) ('ю', (4, 179)) ('г', (7, 174)) ('ф', (2, 161)) ('р', (1, 159)) ('к', (1, 157)) ('б', (2, 156)) ('ж', (1, 136)) ('и', (3, 136)) ('т', (8, 135)) ('п', (9, 133)) ('я', (6, 131)) ('ж', (9, 129)) ('м', (6, 129)) ('х', (1, 129)) ('з', (1, 125)) ('х', (4, 125)) ('э', (15, 93))

# %% [markdown]
# ### Расторгуева Мария СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

def sort1(st):
        return st[1][1]/st[1][0]
lst.sort(key = sort1, reverse = True)
for i in lst:
    print (i)
print ("")
    
def sort2(st):
        return st[1][1]
lst.sort(key=sort2, reverse = True)
for i in range(len(lst)):
    for j in range(i):
        if lst[j][1][1]==lst[j+1][1][1]:
            if lst[j][0]>lst[j+1][0]:
                lst[j], lst[j+1] = lst[j+1], lst[j]
for i in lst:
    print (i)
# Out:
# ('р', (1, 159))
# ('к', (1, 157))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('е', (2, 197))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('е', (7, 184))
# ('г', (7, 174))
# ('я', (6, 131))
# ('м', (6, 129))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
# ('е', (2, 197))
# ('з', (32, 195))
# ('е', (7, 184))
# ('ю', (4, 179))
# ('г', (7, 174))
# ('ф', (2, 161))
# ('р', (1, 159))
# ('к', (1, 157))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('и', (3, 136))
# ('т', (8, 135))
# ('п', (9, 133))
# ('я', (6, 131))
# ('ж', (9, 129))
# ('м', (6, 129))
# ('х', (1, 129))
# ('з', (1, 125))
# ('х', (4, 125))
# ('э', (15, 93))

# %% [markdown]
# ### Гвасалия Метью СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(*sorted(lst,key = lambda x:x[1][1] / x[1][0], reverse = True),'\n', sep = '\n')
print(*sorted(sorted(lst,key = lambda x: x[0]),key = lambda x: x[1][1], reverse = True),sep = '\n')
# Out:
# ('р', (1, 159))
# ('к', (1, 157))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('е', (2, 197))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('е', (7, 184))
# ('г', (7, 174))
# ('я', (6, 131))
# ('м', (6, 129))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
#
# ('е', (2, 197))
# ('з', (32, 195))
# ('е', (7, 184))
# ('ю', (4, 179))
# ('г', (7, 174))
# ('ф', (2, 161))
# ('р', (1, 159))
# ('к', (1, 157))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('и', (3, 136))
# ('т', (8, 135))
# ('п', (9, 133))
# ('я', (6, 131))
# ('ж', (9, 129))
# ('м', (6, 129))
# ('х', (1, 129))
# ('з', (1, 125))
# ('х', (4, 125))
# ('э', (15, 93))

# %% [markdown]
# ### Поддубный Михаил СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print("Первый пункт:")
print(sorted(lst,key=lambda s: s[1][1]/s[1][0], reverse=True))
print("\n\n\nВторой пункт:")
print(sorted(sorted(lst, key=lambda s: s[0]),key=lambda s: s[1][1], reverse=True))
# Out:
# Первый пункт:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
#
#
#
# Второй пункт:
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Миронов Никита СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %% [markdown]
# ### Шубин Никита СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

def sorteq3(mylist):
    for i in range(len(mylist)):
        for j in range(len(mylist)):    
            if (mylist[i][1][1] / mylist[i][1][0]) > (mylist[j][1][1] / mylist[j][1][0]):
                mylist[i], mylist[j] = mylist[j], mylist[i]
                
def sorteq4(mylist):
    for i in range(len(mylist)):
        for j in range(len(mylist)):    
            if mylist[i][1][1] > mylist[j][1][1]:
                mylist[i], mylist[j] = mylist[j], mylist[i]
            elif mylist[i][1][1] == mylist[j][1][1]:
                if mylist[i][0] < mylist[j][0]:
                    mylist[i], mylist[j] = mylist[j], mylist[i]
                    
sorteq3(lst)
print(lst)
print('{:-^120}'.format('space'))
sorteq4(lst)
print(lst)
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# ---------------------------------------------------------space----------------------------------------------------------
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Щеглова Полина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
def sortByRule1(inputStr): # 1. по отношению второго числа из кортежа к первому по убыванию
    return inputStr[1][1]/inputStr[1][0]

def sortByRule2(inputStr): # 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию
    return (-inputStr[1][1], inputStr[0])

lst.sort(key=sortByRule1, reverse=True)
print(lst)

lst.sort(key=sortByRule2)
print(lst)
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Мухамадиева Регина СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
print("пункт 1:")
lst.sort(key=lambda elem: elem[1][1]/elem[1][0], reverse=True)
print(lst)
print("пункт 2:")
lst.sort(key=lambda elem: elem[0],reverse=False)
lst.sort(key=lambda elem: elem[1][1],reverse=True)
print(lst)
# Out:
# пункт 1:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# пункт 2:
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Астраханцев Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1.
sorted(lst, key=lambda t:t[1][1]/t[1][0], reverse=True)
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2.
from functools import reduce
st=sorted(set(e[1][1] for e in lst), reverse=True)
reduce(lambda a,x:a+x, [sorted(filter(lambda t:t[1][1] == s, lst),key=lambda t:t[0]) for s in st])
# Out:
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Бесчастных Роман СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(sorted(lst, key=lambda input: input[1][1]/input[1][0], reverse=True))
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %%
list = sorted(lst, key=lambda input: ord(input[0]))
print(sorted(list, key=lambda tuple: tuple[1][1], reverse=True))
# Out:
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Музаффаров Руфат СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print('1.')
lst = sorted(lst, key = lambda x: x[1][1] / x[1][0], reverse = True)
lst
# Out:
# 1.
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
print('2.')
lst = sorted(lst, key = lambda x: (-x[1][1], ord(x[0])))
lst
# Out:
# 2.
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Гаварина Светлана СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print('1:', *sorted(lst, key=lambda x: (x[1][1] / x[1][0]), reverse=True))
print('2:', *sorted(lst, key=lambda x: (-x[1][1], x[0])))
# Out:
# 1: ('р', (1, 159)) ('к', (1, 157)) ('ж', (1, 136)) ('х', (1, 129)) ('з', (1, 125)) ('е', (2, 197)) ('ф', (2, 161)) ('б', (2, 156)) ('и', (3, 136)) ('ю', (4, 179)) ('х', (4, 125)) ('е', (7, 184)) ('г', (7, 174)) ('я', (6, 131)) ('м', (6, 129)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))
# 2: ('е', (2, 197)) ('з', (32, 195)) ('е', (7, 184)) ('ю', (4, 179)) ('г', (7, 174)) ('ф', (2, 161)) ('р', (1, 159)) ('к', (1, 157)) ('б', (2, 156)) ('ж', (1, 136)) ('и', (3, 136)) ('т', (8, 135)) ('п', (9, 133)) ('я', (6, 131)) ('ж', (9, 129)) ('м', (6, 129)) ('х', (1, 129)) ('з', (1, 125)) ('х', (4, 125)) ('э', (15, 93))

# %% [markdown]
# ### Дундуков Семен СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst.sort(key=lambda x: x[1][1]/x[1][0], reversed=True)
lst
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-27-733d7f4640e1> in <module>()
#      20  ('я', (6, 131))]
#      21
# ---> 22 lst.sort(key=lambda x: x[1][1]/x[1][0], reversed=True)
#      23 lst
#
# TypeError: 'reversed' is an invalid keyword argument for this function

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst.sort(key=lambda x: x[0], reversed=True)
lst.sort(key=lambda x: x[1][1])
lst
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-25-95fc7576d033> in <module>()
#      20  ('я', (6, 131))]
#      21
# ---> 22 lst.sort(key=lambda x: x[0], reversed=True)
#      23 lst.sort(key=lambda x: x[1][1])
#      24 lst
#
# TypeError: 'reversed' is an invalid keyword argument for this function

# %% [markdown]
# ### Бень Таисия СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %% [markdown]
# ### Козликина Татьяна СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# 1. по отношению второго числа из кортежа к первому по убыванию
d = sorted(lst, key = lambda x: (x[1][1]/x[1][0]), reverse = True)

for i in d:
    print(*i)
# Out:
# р (1, 159)
# к (1, 157)
# ж (1, 136)
# х (1, 129)
# з (1, 125)
# е (2, 197)
# ф (2, 161)
# б (2, 156)
# и (3, 136)
# ю (4, 179)
# х (4, 125)
# е (7, 184)
# г (7, 174)
# я (6, 131)
# м (6, 129)
# т (8, 135)
# п (9, 133)
# ж (9, 129)
# э (15, 93)
# з (32, 195)

# %%
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию
d = sorted(lst, key = lambda x: (-x[1][1], x[0]))

for i in d:
    print(*i)
# Out:
# е (2, 197)
# з (32, 195)
# е (7, 184)
# ю (4, 179)
# г (7, 174)
# ф (2, 161)
# р (1, 159)
# к (1, 157)
# б (2, 156)
# ж (1, 136)
# и (3, 136)
# т (8, 135)
# п (9, 133)
# я (6, 131)
# ж (9, 129)
# м (6, 129)
# х (1, 129)
# з (1, 125)
# х (4, 125)
# э (15, 93)

# %% [markdown]
# ### Апресян Тигран СКБ171
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
from pprint import pprint
pprint(sorted(lst,key = lambda b: b[1][1]/b[1][0],reverse = True))
pprint(sorted(sorted(lst, key = lambda a: a[0],reverse = False),key = lambda b: -b[1][1]))
# Out:
# [('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]
# [('е', (2, 197)),
#  ('з', (32, 195)),
#  ('е', (7, 184)),
#  ('ю', (4, 179)),
#  ('г', (7, 174)),
#  ('ф', (2, 161)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('и', (3, 136)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('я', (6, 131)),
#  ('ж', (9, 129)),
#  ('м', (6, 129)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('х', (4, 125)),
#  ('э', (15, 93))]

# %% [markdown]
# ### Долотов Фёдор СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

#1
l1 = sorted(lst, key = lambda x: x[1][1]/x[1][0], reverse = True)

print(l1)
#2
l1 = sorted(lst, key = lambda x: x[0])
l1 = sorted(l1, key = lambda x: x[1][1], reverse=True)
print(l1)
# Out:
# [('р', (1, 159)), ('к', (1, 157)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('е', (2, 197)), ('ф', (2, 161)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('е', (7, 184)), ('г', (7, 174)), ('я', (6, 131)), ('м', (6, 129)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('е', (2, 197)), ('з', (32, 195)), ('е', (7, 184)), ('ю', (4, 179)), ('г', (7, 174)), ('ф', (2, 161)), ('р', (1, 159)), ('к', (1, 157)), ('б', (2, 156)), ('ж', (1, 136)), ('и', (3, 136)), ('т', (8, 135)), ('п', (9, 133)), ('я', (6, 131)), ('ж', (9, 129)), ('м', (6, 129)), ('х', (1, 129)), ('з', (1, 125)), ('х', (4, 125)), ('э', (15, 93))]

# %% [markdown]
# ### Попов Юрий СКБ172
#
# Оценка: -
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по отношению второго числа из кортежа к первому по убыванию
# 2. по второму числу по убыванию, а в случае совпадения по букве по возрастанию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#Задание_9

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]


nlst = list(lst)
# Задание_9.1
def l1(lst):
    a = sorted(lst, key = lambda x: x[1][1] / x[1][0], reverse=True)

    print(*a, sep='\n')
        
    print('      ')


# Задание_9.2
def l2(lst):
    b = sorted(lst, key = lambda x: (-x[1][1], x[0]))

    print(*b, sep='\n')
    
    print('      ')

l1(lst)
l2(lst)
# Out:
# ('р', (1, 159))
# ('к', (1, 157))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('е', (2, 197))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('е', (7, 184))
# ('г', (7, 174))
# ('я', (6, 131))
# ('м', (6, 129))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
# ('е', (2, 197))
# ('з', (32, 195))
# ('е', (7, 184))
# ('ю', (4, 179))
# ('г', (7, 174))
# ('ф', (2, 161))
# ('р', (1, 159))
# ('к', (1, 157))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('и', (3, 136))
# ('т', (8, 135))
# ('п', (9, 133))
# ('я', (6, 131))
# ('ж', (9, 129))
# ('м', (6, 129))
# ('х', (1, 129))
# ('з', (1, 125))
# ('х', (4, 125))
# ('э', (15, 93))
