# %% [markdown]
# -----
# #### Задание 8

# %% [markdown]
# ### Федоров Сергей СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# НОМЕР 1 


lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
sorted(lst, key=lambda lstt: lstt[1][1]-(lstt[1][0])**3, reverse=True) # №1
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
# ЗАДАНИЕ 2
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
r = sorted(lst, key=lambda lstt: lstt[1][0])
# print(r)
t = 0
k = []
for i in range(0,len(r)):
 if i == len(r)-1:
   if r[i][1][0] == r[len(r)-1][1][0]:
       k = k + sorted(r[t:i+1], key=lambda lstt: lstt[0], reverse=1)
       break
   else:
    k.append(r[i])
    k.append((r[len(r)-1]))
    break
 else:
    if r[i][1][0] == r[i+1][1][0]:
        # print(' len = ', len(r), ' t ===== ', t)
        # print(' len = ', len(r), ' i ===== ', i)
        # print(' lenПППППП = ', len(k))
        continue
    else:
        k = k + sorted(r[t:i+1], key=lambda lstt: lstt[0], reverse=1)
        t = i+1


# print(' r[len(r)][1][0]   ===========', r[len(r)][1][0])

# print('len k === ', len(k), "len (r ) = ",len (r))
print(*k, sep='\n')
# Out:
# ('х', (1, 129))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (1, 125))
# ('ж', (1, 136))
# ('ф', (2, 161))
# ('е', (2, 197))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))

# %% [markdown]
# ### Алексеев Кирилл СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]


def Sort1(list):
    i = 0
    characterList = []
    numList = []
    while i < len(list):
        characterList.append(list[i][1][1] - (list[i][1][0] ** 3))
        numList.append(i)
        i = i + 1    
         
    k = len(characterList)
    while k > 0:
        i = 0
        while i < k - 1:
            if characterList[i] < characterList[i + 1]:
                c = characterList[i]
                characterList[i] = characterList[i + 1]
                characterList[i + 1] = c
                c = numList[i]
                numList[i] = numList[i + 1]
                numList[i + 1] = c
            i = i + 1
        k = k - 1
    i = 0
    characterList = []
    while i < len(numList):
        characterList.append(list[numList[i]])
        i = i + 1
    return characterList

def Sort2(list):
    i = 0
    characterList = []
    numList = []
    letterList = []
    while i < len(list):
        characterList.append(list[i][1][0])
        letterList.append(list[i][0])
        numList.append(i)
        i = i + 1
    k = len(characterList)
    while k > 0:
        i = 0
        while i < k - 1:
            if (characterList[i] > characterList[i + 1]) or ((characterList[i] == characterList[i + 1]) and (letterList[i] < letterList[i + 1])):
                c = characterList[i]
                characterList[i] = characterList[i + 1]
                characterList[i + 1] = c
                c = numList[i]
                numList[i] = numList[i + 1]
                numList[i + 1] = c
                p = letterList[i]
                letterList[i] = letterList[i + 1]
                letterList[i + 1] = p
            i = i + 1
        k = k - 1
    characterList = []
    while i < len(numList):
        characterList.append(list[numList[i]])
        i = i + 1
    return characterList
  
print(*Sort1(lst), sep='\n')
print('---')
print(*Sort2(lst), sep='\n')
# Out:
# ('е', (2, 197))
# ('р', (1, 159))
# ('к', (1, 157))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('ю', (4, 179))
# ('и', (3, 136))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
# ---
# ('х', (1, 129))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (1, 125))
# ('ж', (1, 136))
# ('ф', (2, 161))
# ('е', (2, 197))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))

# %% [markdown]
# ### Анчугов Роман СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
import operator as op
new1 = sorted(lst, key = lambda value: value[1][1] - pow(value[1][0], 3), reverse = True)
new2 = sorted(lst, key = lambda value: value[1][0])
i = 0
while i < len(new2):
    start = i
    end = i
    while end < len(new2) and new2[start][1][0] == new2[end][1][0]:
        i += 1
        end = i
    new2[start:end] = sorted(new2[start:end], key=lambda value: value[0], reverse = True)    
(new1, new2)
# Out:
# ([('е', (2, 197)),
#   ('р', (1, 159)),
#   ('к', (1, 157)),
#   ('ф', (2, 161)),
#   ('б', (2, 156)),
#   ('ж', (1, 136)),
#   ('х', (1, 129)),
#   ('з', (1, 125)),
#   ('ю', (4, 179)),
#   ('и', (3, 136)),
#   ('х', (4, 125)),
#   ('я', (6, 131)),
#   ('м', (6, 129)),
#   ('е', (7, 184)),
#   ('г', (7, 174)),
#   ('т', (8, 135)),
#   ('п', (9, 133)),
#   ('ж', (9, 129)),
#   ('э', (15, 93)),
#   ('з', (32, 195))],
#  [('х', (1, 129)),
#   ('р', (1, 159)),
#   ('к', (1, 157)),
#   ('з', (1, 125)),
#   ('ж', (1, 136)),
#   ('ф', (2, 161)),
#   ('е', (2, 197)),
#   ('б', (2, 156)),
#   ('и', (3, 136)),
#   ('ю', (4, 179)),
#   ('х', (4, 125)),
#   ('я', (6, 131)),
#   ('м', (6, 129)),
#   ('е', (7, 184)),
#   ('г', (7, 174)),
#   ('т', (8, 135)),
#   ('п', (9, 133)),
#   ('ж', (9, 129)),
#   ('э', (15, 93)),
#   ('з', (32, 195))])

# %% [markdown]
# ### Акинина Алёна СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = [('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = [('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
print(sorted(lst,key = lambda x : x[1][1] - x[1][0]**3,reverse = True))
print(sorted(sorted(lst,key = lambda x : x[0],reverse = True),key = lambda x : x[1][0]))
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Лисьев Александр СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
sorted(lst, key = lambda x: x[1][1] - x[1][0] ** 3, reverse=True)
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2
sorted(sorted(lst, key = lambda x: x[0], reverse = True), key = lambda x: x[1][0])
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Чердак Александр СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#PART 1

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]


lst = sorted(lst, key = lambda item: item[1][1] - item[1][0]**3, reverse = True)
print(lst)

print('#############')

#PART 2

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst = sorted(lst, key = lambda item: (item[1][0], -ord(item[0])))
print(lst)
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# #############
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Шелепова Алена СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
sorted(lst, key=lambda i: (i[1][1]-i[1][0]**3), reverse = True)
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию
sorted(lst, key=lambda i: (-i[1][0], i[0]), reverse = True)
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Шнейдер Алиса СКБ172
#
# Оценка: 0.5
#
# Комментарий: Second result is wrong.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#Пункт 1
lst.sort(key=lambda x: -x[1][1] + x[1][0] ** 3)
lst
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#Пункт 2
lst.sort(key=lambda x: (x[1][0], x[0]))
lst
# Out:
# [('ж', (1, 136)),
#  ('з', (1, 125)),
#  ('к', (1, 157)),
#  ('р', (1, 159)),
#  ('х', (1, 129)),
#  ('б', (2, 156)),
#  ('е', (2, 197)),
#  ('ф', (2, 161)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('ю', (4, 179)),
#  ('м', (6, 129)),
#  ('я', (6, 131)),
#  ('г', (7, 174)),
#  ('е', (7, 184)),
#  ('т', (8, 135)),
#  ('ж', (9, 129)),
#  ('п', (9, 133)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Зайцева Анастасия СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
lst.sort(key = lambda i: i[1][1] - (i[1][0])**3 , reverse = True)
lst
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst.sort(key = lambda i: i[0], reverse = True)
lst.sort(key = lambda i: i[1][0])
lst
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Полуяктов Анатолий СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
task1=sorted(lst, key= lambda x:x[1][1]-x[1][0]**3,reverse=True)
task1
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
task2=sorted(lst,key=lambda x:x[0],reverse=True)
task2=sorted(task2,key=lambda x:x[1][0])
task2
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Фомин Андрей СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(sorted(lst, key= lambda x: x[1][1] - x[1][0] ** 3, reverse=True))
print()
# 2 пункт
lst.sort(key= lambda x : x[0], reverse=True)
lst.sort(key= lambda x: x[1][0])
print(lst)
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
#
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Марипова Жасмин СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst1 = sorted(lst, key = lambda x: x[1][1] - x[1][0]**3, reverse = True) # 1 задание
lst1
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst2 = sorted(lst, key = lambda x: (x[1][0], -ord(x[0]))) # 2 задание
lst2
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Зоричев Борис СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
lst.sort(key=lambda i: i[1][1] - i[1][0]**3, reverse = True)
print(lst)
lst.sort(key=lambda i: (i[1][0], -ord(i[0])))
print(lst)
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Сербаев Вадим СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst1 = lst

#1
def ListSort1(lst):
        return lst[1][1]-(lst[1][0])*(lst[1][0])*(lst[1][0])
lst.sort(key=ListSort1, reverse = True)
print(lst)

#2
def ListSort2(lst1):
        return lst1[1][0]
lst1.sort(key=ListSort2)

def ListSortAlphabet(lst2):
        return lst2[0]

def AfterListSort(lst1):
    finallist=[]
    lst2=[]
    i=0
    while i<len(lst1):
        ireg = i
        reg = lst1[i][1][0]
        while ireg<len(lst1):
            if(lst1[ireg][1][0]==reg):
                lst2.append(lst1[ireg])
                i = ireg
            ireg+=1
        lst2.sort(key=ListSortAlphabet, reverse = True)
        #print(lst2)
        finallist.extend(lst2)
        lst2=[]
        #print(i)
        i+=1
    print(finallist)
        
AfterListSort(lst1)
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Булгаков Виталий СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
a1 = sorted(lst, key = lambda x : x[1][1] - x[1][0] ** 3, reverse = True)
#a = sorted(lst, key = lambda x : - (x[1][1] - x[1][0] ** 3)) работает точно так же, вроде...
a2 = sorted(sorted(lst, key = lambda x: x[0], reverse = True), key = lambda x: x[1][0])
print(a1, a2) #для удобочитаемой версии вывода, лучше выводить по отдельности a1 и a2
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))] [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Андреева Влада СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
a = sorted(lst, key=lambda i: i[1][1] - (i[1][0])**3, reverse=True)
print('Лист, отсортированный по условию в #1:\n', a, '\n')

#2
a = sorted(lst, key=lambda i: i[1][0])
final = []
i = 0
while i < len(a):
    l = [a[i]]
    if i == 0:
        if a[0][1][0] == a[1][1][0]:
            l.append(a[1])
            i += 1
    i += 1
    if i < len(a):
        while a[i][1][0] == a[i-1][1][0] and 0 < i < len(a):
            l.append(a[i])
            i += 1
        l = sorted(l, key=lambda i: i[0], reverse=True)
    final.extend(l)
print('Лист, отсортированный по условию в #2\n', final)
# Out:
# Лист, отсортированный по условию в #1:
#  [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
#
# Лист, отсортированный по условию в #2
#  [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Клопов Владислав СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst.sort(key=lambda x: x[1][1]-(x[1][0]**3),reverse=True)
lst
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst.sort(key=lambda x: x[1][0]-ord(x[0])/1000)
lst
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Сарахан Владислав СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
def first(a):
    return -(a[1][1] - a[1][0]**3)

# %%
sorted(lst, key=first)
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
def second(a):
    return a[1][0] - ord(a[0]) / 100

# %%
sorted(lst, key=second)
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Старостин Данила СКБ172
#
# Оценка: 0.5
#
# Комментарий: Second result is wrong.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
lst2 = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

def func(lst):
    return -lst[1][1] + lst[1][0]**3

def func2(lst2):
    return -lst2[1][0], lst[0] 

lst.sort(key=func)
lst2.sort(key=func2, reverse = True)
print(*lst)
print(*lst2)
# Out:
# ('е', (2, 197)) ('р', (1, 159)) ('к', (1, 157)) ('ф', (2, 161)) ('б', (2, 156)) ('ж', (1, 136)) ('х', (1, 129)) ('з', (1, 125)) ('ю', (4, 179)) ('и', (3, 136)) ('х', (4, 125)) ('я', (6, 131)) ('м', (6, 129)) ('е', (7, 184)) ('г', (7, 174)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))
# ('ж', (1, 136)) ('з', (1, 125)) ('к', (1, 157)) ('р', (1, 159)) ('х', (1, 129)) ('б', (2, 156)) ('е', (2, 197)) ('ф', (2, 161)) ('и', (3, 136)) ('х', (4, 125)) ('ю', (4, 179)) ('м', (6, 129)) ('я', (6, 131)) ('г', (7, 174)) ('е', (7, 184)) ('т', (8, 135)) ('ж', (9, 129)) ('п', (9, 133)) ('э', (15, 93)) ('з', (32, 195))

# %% [markdown]
# ### Стрекнев Денис СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
l1=sorted(lst, key=lambda x: x[1][1]-x[1][0]**3, reverse=True)
l1
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2
l1=sorted(lst, key=lambda x: x[0][0], reverse=True)
l1=sorted(l1, key=lambda x: x[1][0])
l1
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Дородный Дмитрий СКБ172
#
# Оценка: 0.5
#
# Комментарий: First result is wrong.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(*sorted(lst, key = lambda x: x[1][1]-x[1][0]**3), '', *sorted(sorted(lst, key = lambda x: x[0], reverse = True), key = lambda x: x[1][0]), sep = '\n')
# Out:
# ('з', (32, 195))
# ('э', (15, 93))
# ('ж', (9, 129))
# ('п', (9, 133))
# ('т', (8, 135))
# ('г', (7, 174))
# ('е', (7, 184))
# ('м', (6, 129))
# ('я', (6, 131))
# ('х', (4, 125))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('з', (1, 125))
# ('х', (1, 129))
# ('ж', (1, 136))
# ('б', (2, 156))
# ('ф', (2, 161))
# ('к', (1, 157))
# ('р', (1, 159))
# ('е', (2, 197))
#
# ('х', (1, 129))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (1, 125))
# ('ж', (1, 136))
# ('ф', (2, 161))
# ('е', (2, 197))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))

# %% [markdown]
# ### Шемякин Дмитрий СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

#1
lst = sorted(lst, key = lambda x: x[1][1] - x[1][0]**3, reverse = True)

lst
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

#2
lst = sorted(lst, key = lambda x: (x[1][0], -ord(x[0])))

lst
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Никитина Елизавета СКБ171
#
# Оценка: 0
#
# Комментарий: Result is wrong.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

def sort1(val):
    [x, y] = val[1]
    return y-x^3

lst.sort(key=sort1, reverse=True)
print([ a[0] for a in lst ])
print('---')
# --
arr = [(a[0], a[1][0]) for a in lst]
arr2sort = {}
for a in arr:
    if a[1] not in arr2sort:
        arr2sort[a[1]] = []
    arr2sort[a[1]].append(a[0])
result = []
for a in sorted(arr2sort.keys()):
    arr2sort[a].sort(reverse=True)
    result += arr2sort[a]
print(result)
# Out:
# ['е', 'е', 'ю', 'г', 'з', 'к', 'р', 'ф', 'б', 'и', 'ж', 'х', 'з', 'п', 'я', 'т', 'ж', 'х', 'м', 'э']
# ---
# ['х', 'р', 'к', 'з', 'ж', 'ф', 'е', 'б', 'и', 'ю', 'х', 'я', 'м', 'е', 'г', 'т', 'п', 'ж', 'э', 'з']

# %% [markdown]
# ### Семенов Игорь СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print('#1 ',sorted(lst, key=lambda t:t[1][1]-t[1][0]**3, reverse=True))
print("---------------------------------------")
print('#2 ',sorted(lst, key=lambda t:t[1][0]*1000000-ord(t[0])))
# Out:
# #1  [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# ---------------------------------------
# #2  [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Шамрин Игорь СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
sorted(lst, key = lambda x: x[1][1] - x[1][0]**3)
sorted(sorted(lst, key = lambda x: x[0], reverse = True), key = lambda x: x[1][0])
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Щербаков Игорь СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
s1 = sorted(lst, key=lambda t:t[1][1]-(t[1][0])**3, reverse=True) # 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
for item in s1:
    print(item)
print('\n')

def doublesort(x, primary, secondary, primary_reverse=False, secondary_reverse=False): #Для обобщения решения
    s=sorted(x, key=secondary, reverse=secondary_reverse)
    s=sorted(s, key=primary, reverse=primary_reverse)
    return s

s2= doublesort(lst,primary= lambda t: t[1][0], secondary =lambda t: t[0],secondary_reverse=True) # 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию
for item in s2:
    print(item)
# Out:
# ('е', (2, 197))
# ('р', (1, 159))
# ('к', (1, 157))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('ю', (4, 179))
# ('и', (3, 136))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
#
# ('х', (1, 129))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (1, 125))
# ('ж', (1, 136))
# ('ф', (2, 161))
# ('е', (2, 197))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))

# %% [markdown]
# ### Шомахов Идар СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst = sorted(lst, key = lambda x: x[1][1] - x[1][0]**3, reverse = True) # 1 задание
lst
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst = sorted(lst, key = lambda x: (x[1][0], -ord(x[0]))) # 2 задание
lst
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Григорьев Илья СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

print(sorted(lst, key = (lambda n:n[1][1] - n[1][0] ** 3), reverse = True)) #1
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

print(sorted(sorted(lst, key = lambda n:n[0], reverse = True), key = lambda n:n[1][0])) #2
# Out:
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Фомин Илья СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
sorted(lst,key=lambda x:-(x[1][1]-x[1][0]**3))
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2
sorted(lst,key=lambda x:(-x[1][0],x[0]),reverse=True)
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Синицын Константин СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1
print(sorted(lst, key = lambda x: x[1][1] - x[1][0] ** 3, reverse = True))
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %%
#2
print(sorted(sorted(lst, key = lambda x: x[0], reverse = True), key = lambda x: x[1][0]))
# Out:
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Смирнов Константин СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(*sorted(lst, key=lambda i: i[1][1] - i[1][0]**3, reverse=True))
# Out:
# ('е', (2, 197)) ('р', (1, 159)) ('к', (1, 157)) ('ф', (2, 161)) ('б', (2, 156)) ('ж', (1, 136)) ('х', (1, 129)) ('з', (1, 125)) ('ю', (4, 179)) ('и', (3, 136)) ('х', (4, 125)) ('я', (6, 131)) ('м', (6, 129)) ('е', (7, 184)) ('г', (7, 174)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))

# %%
from fn import _
print(*sorted(sorted(lst, key=_[0], reverse=True), key=_[1][0]))
# Out:
# ('х', (1, 129)) ('р', (1, 159)) ('к', (1, 157)) ('з', (1, 125)) ('ж', (1, 136)) ('ф', (2, 161)) ('е', (2, 197)) ('б', (2, 156)) ('и', (3, 136)) ('ю', (4, 179)) ('х', (4, 125)) ('я', (6, 131)) ('м', (6, 129)) ('е', (7, 184)) ('г', (7, 174)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))

# %% [markdown]
# ### Расторгуева Мария СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

def sort1(st):
        return st[1][1] - st[1][0]**3
lst.sort(key = sort1, reverse = True)
for i in lst:
    print (i)
print ("")
    
def sort2(st):
        return st[1][0]
lst.sort(key=sort2)
for i in range(len(lst)):
    for j in range(i):
        if lst[j][1][0]==lst[j+1][1][0]:
            if lst[j][0]<lst[j+1][0]:
                lst[j], lst[j+1] = lst[j+1], lst[j]
for i in lst:
    print (i)
# Out:
# ('е', (2, 197))
# ('р', (1, 159))
# ('к', (1, 157))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('ю', (4, 179))
# ('и', (3, 136))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
# ('х', (1, 129))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (1, 125))
# ('ж', (1, 136))
# ('ф', (2, 161))
# ('е', (2, 197))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))

# %% [markdown]
# ### Гвасалия Метью СКБ172
#
# Оценка: 0.5
#
# Комментарий: First result is wrong.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
newl1 = sorted(lst,key = lambda x: x[1][1] - x[1][0]^3)
print(*newl1,sep='\n')
print('\n')
newl2 = sorted(lst,key= lambda x: x[0],reverse = True)
print(*sorted(newl2,key = lambda x: x[1][0]),sep='\n')
# Out:
# ('э', (15, 93))
# ('м', (6, 129))
# ('х', (4, 125))
# ('ж', (9, 129))
# ('т', (8, 135))
# ('я', (6, 131))
# ('з', (1, 125))
# ('п', (9, 133))
# ('х', (1, 129))
# ('ж', (1, 136))
# ('и', (3, 136))
# ('б', (2, 156))
# ('ф', (2, 161))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (32, 195))
# ('г', (7, 174))
# ('ю', (4, 179))
# ('е', (7, 184))
# ('е', (2, 197))
#
#
# ('х', (1, 129))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (1, 125))
# ('ж', (1, 136))
# ('ф', (2, 161))
# ('е', (2, 197))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))

# %% [markdown]
# ### Поддубный Михаил СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print("Первый пункт:")
print(sorted(lst, key=lambda s: s[1][1]-s[1][0]**3, reverse=True))
print("\n\n\nВторой пункт:")
print(sorted(sorted(lst, key=lambda s: s[0], reverse=True),key=lambda s: s[1][0]))
# Out:
# Первый пункт:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
#
#
#
# Второй пункт:
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Миронов Никита СКБ171
#
# Оценка: 0
#
# Комментарий: No solution.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %% [markdown]
# ### Шубин Никита СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

def sorteq1(mylist):
    for i in range(len(mylist)):
        for j in range(len(mylist)):    
            if (mylist[i][1][1] - (mylist[i][1][0] ** 3)) > (mylist[j][1][1] - (mylist[j][1][0] ** 3)):
                mylist[i], mylist[j] = mylist[j], mylist[i]
                
def sorteq2(mylist):
    for i in range(len(mylist)):
        for j in range(len(mylist)):    
            if mylist[i][1][0] < mylist[j][1][0]:
                mylist[i], mylist[j] = mylist[j], mylist[i]
            elif mylist[i][1][0] == mylist[j][1][0]:
                if mylist[i][0] > mylist[j][0]:
                    mylist[i], mylist[j] = mylist[j], mylist[i]
                    
sorteq1(lst)
print(lst)
print('{:-^120}'.format('space'))
sorteq2(lst)
print(lst)
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# ---------------------------------------------------------space----------------------------------------------------------
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Щеглова Полина СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
def sortByRule1(inputStr): # 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
    return inputStr[1][1] - inputStr[1][0]**3

def sortByRule2(inputStr): # 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию
    return (-inputStr[1][0], inputStr[0])

lst.sort(key=sortByRule1, reverse=True)
print(lst)

lst.sort(key=sortByRule2, reverse=True)
print(lst)
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Мухамадиева Регина СКБ172
#
# Оценка: 0.5
#
# Комментарий: First result is wrong.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
print("пункт 1:")
lst.sort(key = lambda elem: elem[1][1]-elem[1][0]**3)
print(lst)
print("пункт 2:")
lst.sort(key=lambda elem: elem[0],reverse=True)
lst.sort(key=lambda elem: elem[1][0])
print(lst)
# Out:
# пункт 1:
# [('з', (32, 195)), ('э', (15, 93)), ('ж', (9, 129)), ('п', (9, 133)), ('т', (8, 135)), ('г', (7, 174)), ('е', (7, 184)), ('м', (6, 129)), ('я', (6, 131)), ('х', (4, 125)), ('и', (3, 136)), ('ю', (4, 179)), ('з', (1, 125)), ('х', (1, 129)), ('ж', (1, 136)), ('б', (2, 156)), ('ф', (2, 161)), ('к', (1, 157)), ('р', (1, 159)), ('е', (2, 197))]
# пункт 2:
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Астраханцев Роман СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
#1.
sorted(lst, key=lambda t:t[1][1]-t[1][0]**3, reverse=True)
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
#2.
from functools import reduce
st=sorted(set(e[1][0] for e in lst))
reduce(lambda a,x:a+x,[sorted(filter(lambda t:t[1][0] == s, lst),key=lambda t:t[0], reverse=True) for s in st])
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Бесчастных Роман СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print(sorted(lst, key=lambda tuple: tuple[1][1] - tuple[1][0]**3, reverse=True))
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %%
list = sorted(lst, key=lambda input: ord(input[0]), reverse=True)
print(sorted(list, key=lambda tuple: tuple[1][0]))
# Out:
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Музаффаров Руфат СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

print('1.')
lst = sorted(lst, key = lambda x: x[1][1] - x[1][0]**3, reverse = True)
lst
# Out:
# 1.
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
print('2.')
lst = sorted(lst, key = lambda x: (x[1][0], -ord(x[0])))
lst
# Out:
# 2.
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Гаварина Светлана СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
print('1:', *sorted(lst, key=lambda x: x[1][1] - x[1][0] ** 3, reverse=True))
print('2:', *sorted(lst, key=lambda x: (-x[1][0], x[0]), reverse=True))
# Out:
# 1: ('е', (2, 197)) ('р', (1, 159)) ('к', (1, 157)) ('ф', (2, 161)) ('б', (2, 156)) ('ж', (1, 136)) ('х', (1, 129)) ('з', (1, 125)) ('ю', (4, 179)) ('и', (3, 136)) ('х', (4, 125)) ('я', (6, 131)) ('м', (6, 129)) ('е', (7, 184)) ('г', (7, 174)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))
# 2: ('х', (1, 129)) ('р', (1, 159)) ('к', (1, 157)) ('з', (1, 125)) ('ж', (1, 136)) ('ф', (2, 161)) ('е', (2, 197)) ('б', (2, 156)) ('и', (3, 136)) ('ю', (4, 179)) ('х', (4, 125)) ('я', (6, 131)) ('м', (6, 129)) ('е', (7, 184)) ('г', (7, 174)) ('т', (8, 135)) ('п', (9, 133)) ('ж', (9, 129)) ('э', (15, 93)) ('з', (32, 195))

# %% [markdown]
# ### Дундуков Семен СКБ171
#
# Оценка: 0
#
# Комментарий: Python error.

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

lst.sort(key=lambda x: x[1][1]-x[1][0] ** 3, reversed=True)
lst
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-ac64c995e29e> in <module>
#      21  ('я', (6, 131))]
#      22
# ---> 23 lst.sort(key=lambda x: x[1][1]-x[1][0] ** 3, reversed=True)
#      24 lst
#
# TypeError: 'reversed' is an invalid keyword argument for sort()

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]
lst.sort(key=lambda x: x[0])
lst.sort(key=lambda x: x[1][1], reversed=True)
lst
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-c9906a451c0d> in <module>
#      21  ('я', (6, 131))]
#      22 lst.sort(key=lambda x: x[0])
# ---> 23 lst.sort(key=lambda x: x[1][1], reversed=True)
#      24 lst
#
# TypeError: 'reversed' is an invalid keyword argument for sort()

# %% [markdown]
# ### Бень Таисия СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
sorted(lst, key = lambda el: el[1][1]-(el[1][0])**3,reverse=True)
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %%
def Sort(tup): 
    return(sorted(tup, key = lambda x: x[0], reverse = True)) 

S = sorted(lst, key = lambda el: el[1][0])
numbs = []
for e in S :
    if e[1][0] not in numbs:
        numbs += [e[1][0]]
ans = []
for n in numbs:
    l = list(filter(lambda x: x[1][0]==n, lst))
    ans+=Sort(l)
ans
# Out:
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Козликина Татьяна СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
d = sorted(lst, key = lambda x: x[1][1]-x[1][0]**3, reverse = True)

for i in d:
    print(*i)
# Out:
# е (2, 197)
# р (1, 159)
# к (1, 157)
# ф (2, 161)
# б (2, 156)
# ж (1, 136)
# х (1, 129)
# з (1, 125)
# ю (4, 179)
# и (3, 136)
# х (4, 125)
# я (6, 131)
# м (6, 129)
# е (7, 184)
# г (7, 174)
# т (8, 135)
# п (9, 133)
# ж (9, 129)
# э (15, 93)
# з (32, 195)

# %%
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию
d = sorted(lst, key = lambda x: (-x[1][0], x[0]), reverse = True)

for i in d:
    print(*i)
# Out:
# х (1, 129)
# р (1, 159)
# к (1, 157)
# з (1, 125)
# ж (1, 136)
# ф (2, 161)
# е (2, 197)
# б (2, 156)
# и (3, 136)
# ю (4, 179)
# х (4, 125)
# я (6, 131)
# м (6, 129)
# е (7, 184)
# г (7, 174)
# т (8, 135)
# п (9, 133)
# ж (9, 129)
# э (15, 93)
# з (32, 195)

# %% [markdown]
# ### Апресян Тигран СКБ171
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
from pprint import pprint
pprint(sorted(lst, key = lambda a:a[1][1]-a[1][0]**3,reverse = True))
pprint(sorted(sorted(lst, key = lambda a: a[0],reverse = True), key = lambda a:a[1][0],reverse = False))
# Out:
# [('е', (2, 197)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('ф', (2, 161)),
#  ('б', (2, 156)),
#  ('ж', (1, 136)),
#  ('х', (1, 129)),
#  ('з', (1, 125)),
#  ('ю', (4, 179)),
#  ('и', (3, 136)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]
# [('х', (1, 129)),
#  ('р', (1, 159)),
#  ('к', (1, 157)),
#  ('з', (1, 125)),
#  ('ж', (1, 136)),
#  ('ф', (2, 161)),
#  ('е', (2, 197)),
#  ('б', (2, 156)),
#  ('и', (3, 136)),
#  ('ю', (4, 179)),
#  ('х', (4, 125)),
#  ('я', (6, 131)),
#  ('м', (6, 129)),
#  ('е', (7, 184)),
#  ('г', (7, 174)),
#  ('т', (8, 135)),
#  ('п', (9, 133)),
#  ('ж', (9, 129)),
#  ('э', (15, 93)),
#  ('з', (32, 195))]

# %% [markdown]
# ### Долотов Фёдор СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

#1
l1 = sorted(lst, key = lambda x: x[1][1] - x[1][0]**3, reverse = True)

print(l1)
#2
l1 = sorted(lst, key = lambda x: x[0], reverse = True)
l1 = sorted(l1, key = lambda x: x[1][0])

print(l1)
# Out:
# [('е', (2, 197)), ('р', (1, 159)), ('к', (1, 157)), ('ф', (2, 161)), ('б', (2, 156)), ('ж', (1, 136)), ('х', (1, 129)), ('з', (1, 125)), ('ю', (4, 179)), ('и', (3, 136)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]
# [('х', (1, 129)), ('р', (1, 159)), ('к', (1, 157)), ('з', (1, 125)), ('ж', (1, 136)), ('ф', (2, 161)), ('е', (2, 197)), ('б', (2, 156)), ('и', (3, 136)), ('ю', (4, 179)), ('х', (4, 125)), ('я', (6, 131)), ('м', (6, 129)), ('е', (7, 184)), ('г', (7, 174)), ('т', (8, 135)), ('п', (9, 133)), ('ж', (9, 129)), ('э', (15, 93)), ('з', (32, 195))]

# %% [markdown]
# ### Попов Юрий СКБ172
#
# Оценка: 1
#
# Комментарий: -

# %%
# отсортировать список lst:
# 1. по убыванию по следующему критерию: y-x^3, где y - второе число кортежа, а x - первое
# 2. по первому числу кортежа по возрастаню, а в случае совпадения - по букве по убыванию

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]

# %%
# Задание_8

lst = \
[('б', (2, 156)),
 ('г', (7, 174)),
 ('е', (2, 197)),
 ('е', (7, 184)),
 ('ж', (1, 136)),
 ('ж', (9, 129)),
 ('з', (1, 125)),
 ('з', (32, 195)),
 ('и', (3, 136)),
 ('к', (1, 157)),
 ('м', (6, 129)),
 ('п', (9, 133)),
 ('р', (1, 159)),
 ('т', (8, 135)),
 ('ф', (2, 161)),
 ('х', (1, 129)),
 ('х', (4, 125)),
 ('э', (15, 93)),
 ('ю', (4, 179)),
 ('я', (6, 131))]


nlst = list(lst)
# Задание_8.1
def l1(lst):
    a = sorted(lst, key = lambda x: x[1][1] - x[1][0] ** 3, reverse=True)
    
    print(*a, sep='\n')
    
    print('      ')


#Задание_8.2
def l2(lst):
    
    b = sorted(nlst, key = lambda x: (-x[1][0], x[0]),reverse=True)
    
    print(*b, sep='\n')


l1(lst)
l2(lst)
# Out:
# ('е', (2, 197))
# ('р', (1, 159))
# ('к', (1, 157))
# ('ф', (2, 161))
# ('б', (2, 156))
# ('ж', (1, 136))
# ('х', (1, 129))
# ('з', (1, 125))
# ('ю', (4, 179))
# ('и', (3, 136))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
#
# ('х', (1, 129))
# ('р', (1, 159))
# ('к', (1, 157))
# ('з', (1, 125))
# ('ж', (1, 136))
# ('ф', (2, 161))
# ('е', (2, 197))
# ('б', (2, 156))
# ('и', (3, 136))
# ('ю', (4, 179))
# ('х', (4, 125))
# ('я', (6, 131))
# ('м', (6, 129))
# ('е', (7, 184))
# ('г', (7, 174))
# ('т', (8, 135))
# ('п', (9, 133))
# ('ж', (9, 129))
# ('э', (15, 93))
# ('з', (32, 195))
